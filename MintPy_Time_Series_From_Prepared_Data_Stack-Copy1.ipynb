# %% [markdown]
# ![SAR, InSAR, PolSAR, and banner](https://opensarlab-docs.asf.alaska.edu/opensarlab-notebook-assets/notebook_images/blackboard-banner.png)
#
# # InSAR Time Series Analysis using MintPy and HyP3 products
#
# **Author:** Alex Lewandowski; University of Alaska Fairbanks
#
# Based on the [LosAngeles_time_series](https://github.com/ASFOpenSARlab/opensarlab-notebooks/blob/master/SAR_Training/English/Hazards/LosAngeles_time_series.ipynb) notebook by Eric Fielding, David Bekaert, Heresh Fattahi and Yunjun Zhang, which uses an example ARIA dataset.
#
# <img src="https://opensarlab-docs.asf.alaska.edu/opensarlab-notebook-assets/notebook_images/UAFLogo_A_647.png" width="170" align="right"/>
#
#
# ## Mapping surface deformation with InSAR time series
#
# This notebook demonstrates how to create an InSAR time series with MintPy using an ASF HyP3 InSAR data stack, which can be ordered on [ASF Data Search/Vertex](https://search.asf.alaska.edu/#/) and prepared using the [Prepare_HyP3_InSAR_Stack_for_MintPy](https://github.com/ASFOpenSARlab/opensarlab-notebooks/blob/master/SAR_Training/English/Master/Prepare_HyP3_InSAR_Stack_for_MintPy.ipynb) notebook.
#
#
# It also explores how to assess the quality of the stack inversion, temporal coherence, and velocity errors.
#
# **Important Note about JupyterHub**
# Your JupyterHub server will automatically shutdown when left idle for more than 1 hour. Your notebooks will not be lost but you will have to restart their kernels and re-run them from the beginning. You will not be able to seamlessly continue running a partially run notebook.
#
# <br>
# <hr>
# <div class="alert alert-success">
# <font face="Calibri" size="5"><b><font color='rgba(200,0,0,0.2)'> <u>This Notebook supports MintPy 1.5.1</u></font></b></font>
#
# <font face="Calibri" size="3">SBAS time series may be successfully performed using HyP3 S1 GAMMA InSAR and HyP3 S1 ISCE InSAR Burst data with MintPY 1.5.3, but many of the plots demonstrated in this notebook are break due to a lack of full support for UTM. This does not impact the correct geocoding of the output data, but it does impact this notebook. We hope to submit a Pull Request to MintPy soon to add additional UTM support. We will update this notebook at that time.
# </font>
# </div>

# %%
import url_widget as url_w
notebookUrl = url_w.URLWidget()
display(notebookUrl)
# Out:
# URLWidget()

# %%
from IPython.display import Markdown
from IPython.display import display

notebookUrl = notebookUrl.value
user = !echo $JUPYTERHUB_USER
env = !echo $CONDA_PREFIX
if env[0] == '':
    env[0] = 'Python 3 (base)'
if env[0] != '/home/jovyan/.local/envs/osl_mintpy':
    display(Markdown(f'<text style=color:red><strong>WARNING:</strong></text>'))
    display(Markdown(f'<text style=color:red>This notebook should be run using the "osl_mintpy" conda environment.</text>'))
    display(Markdown(f'<text style=color:red>It is currently using the "{env[0].split("/")[-1]}" environment.</text>'))
    display(Markdown(f'<text style=color:red>Select "osl_mintpy" from the "Change Kernel" submenu of the "Kernel" menu.</text>'))
    display(Markdown(f'<text style=color:red>If the "osl_mintpy" environment is not present, use <a href="{notebookUrl.split("/user")[0]}/user/{user[0]}/notebooks/conda_environments/Create_OSL_Conda_Environments.ipynb"> Create_OSL_Conda_Environments.ipynb </a> to create it.</text>'))
    display(Markdown(f'<text style=color:red>Note that you must restart your server after creating a new environment before it is usable by notebooks.</text>'))

# %% [markdown]
# # 0: Notebook setup
#
# **Import necessary packages**

# %%
import base64
import contextlib
import csv
from datetime import datetime, timedelta
from getpass import getpass
import os
from pathlib import Path
import re
import shutil
from typing import Union
import zipfile

import h5py
from ipyfilechooser import FileChooser
import numpy as np
from osgeo import gdal, osr
gdal.UseExceptions()

from pandas.core.frame import DataFrame
import rasterio
from rasterio.transform import from_origin
from rasterio.warp import transform_bounds, transform
import rioxarray as rxr
from tqdm.notebook import tqdm
import urllib
import xarray as xr

from bokeh.plotting import figure, show, output_file, ColumnDataSource, output_notebook
from bokeh.models import LabelSet, Div
import bokeh.layouts

import ipywidgets as widgets
from ipywidgets import Layout

from mintpy.cli import view, tsview, plot_network, plot_transection, plot_coherence_matrix
import mintpy.plot_coherence_matrix
import mintpy.objects.insar_vs_gps
import mintpy.utils

import opensarlab_lib as asfn

# %% [markdown]
# **Select the directory holding your MintPy-ready HyP3 data stack and/or MintPy directory from a previously loaded MintPy SBAS stack**
# - Click the `Select` button
# - Navigate to your data directory
# - Click the `Select` button
# - Confirm that the desired path appears in green text
# - Click the `Change` button to alter your selection

# %%
path = Path.cwd()
fc = FileChooser(path)
display(fc)
# Out:
# FileChooser(path='/home/jovyan/notebooks/SAR_Training/English/Master', filename='', title='', show_hidden=Fals…

# %% [markdown]
# **Define a project name and create a MintPy directory in which to store files output during our analysis**

# %%
# define the work directory
work_path = Path(fc.selected_path)
print(f"Work directory: {work_path}")

# define a project name
proj_name = input("Enter a project name: ")

# define the MintPy time-series directory
mint_path = work_path/'MintPy'
mint_path.mkdir(exist_ok=True)
print(f"MintPy directory: {mint_path}")

#create a directory in which to store plots
plot_path = mint_path/"plots"
plot_path.mkdir(exist_ok=True)
# Out:
# Work directory: /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only
# Enter a project name:  tuscon
# MintPy directory: /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy

# %% [markdown]
# # 1. Add Your Climate Data Store (CDS) UID & API Key to the Pyaps3 Config
#
# ### This step only needs to be completed once and may be skipped if you have already updated the CDS config
#
# - Running the MintPy smallbaselineApp's `correct_troposphere` step requires downloading atmospheric pressure data from the CDS
# - If don't yet have a CDS API key:
#     - Proceed to [CDS](https://cds.climate.copernicus.eu/cdsapp#!/home) and create an account
#     - Open the [Datasets page](https://cds.climate.copernicus.eu/cdsapp#!/search?type=dataset)
#     - Search for "ERA5"
#     - Select any of ERA5 datasets that appear
#     - Select the `Download data` tab
#     - Scroll to the bottom of the screen
#     - Accept the `Terms of use`
#     - Click on your name at the top right of the screen to access your profile page
#     - Your `UID` and `API Key` will be displayed here
# - Run the following 2 code cells to update the pyaps config from this notebook **OR** open an OpenSARlab terminal and complete the following steps:
#     - Use vim or another text editor to open the `~/.cdsapirc` config file
#         - Add the CDS url to the first line of the config and your CDS `UID` and CDS`API Key` to the 2nd line of the config
#             - This should be formatted like:
#                 - url: https://cds.climate.copernicus.eu/api/v2\
#                 - key: your_UID: your_API_Key
#         - Save the config and exit the text editor
#
# **If you do not add your CDS credentials to `~/.cdsapirc`, the `correct_troposphere` step will fail**

# %%
pyaps_cfg = Path("/home/jovyan/.cdsapirc")
try:
    with open(pyaps_cfg, 'r') as f:
        lines = f.readlines()
        if len(lines) == 2 and 'url' in lines[0]:
            print("There was a CDS UID and API Key found in the pyaps3 config: ~/.cdsapirc")
            print("Would you like to update them?")
            update_cds_cfg = asfn.select_parameter(["Do not update CDS UID and API Key", 
                                                    "Update CDS UID and API Key"])
            display(update_cds_cfg)
        else:
            update_cds_cfg = None
except FileNotFoundError:
    update_cds_cfg = None

# %%
if not update_cds_cfg or "Update" in update_cds_cfg.value:
    with open(pyaps_cfg, 'w') as f:
            uid = input("Enter your CDS UID")
            key = getpass("Enter your CDS API Key")
            lines = ['', '']
            lines[0] = f"url: https://cds.climate.copernicus.eu/api/v2\n"
            lines[1] = f"key: {uid}:{key}\n"
            f.seek(0)
            f.writelines(lines)
            f.truncate()

# %% [markdown]
# # 2. smallbaselineApp.py overview

# %% [markdown]
# This application provides a workflow which includes several steps to invert a stack of unwrapped interferograms and apply different corrections to obtain ground displacement timeseries.
# The workflow consists of two main blocks:
#
# * correcting unwrapping errors and inverting for the raw phase time-series (blue ovals),
# * correcting for noise from different sources to obtain the displacement time-series (green ovals).
#
# Some steps are optional, which are switched off by default (marked by dashed boundaries). Configuration parameters for each step are initiated with default values in a customizable text file: [smallbaselineApp.cfg](https://github.com/insarlab/MintPy/blob/master/mintpy/defaults/smallbaselineApp.cfg). In this notebook, we will walk through some of these steps, for a complete example see the [MintPy repository](https://github.com/insarlab/MintPy).
#
#
# <p align="left">
#   <img width="600" src="https://opensarlab-docs.asf.alaska.edu/opensarlab-notebook-assets/notebook_images/MintPyWorkflow.jpg">
# </p>
# <p style="text-align: center;">
#     (Figure from Yunjun et al., 2019)
# </p>

# %% [markdown]
# ## 2.1. Processing steps of smallbaselineApp.py

# %% [markdown]
# The MintPy **smallbaselineApp.py** application provides a workflow to invert a stack of unwrapped interferograms and apply different (often optional) corrections to obtain ground displacement timeseries. A detailed overview of the options can be retrieved by involking the help option:

# %%
# !smallbaselineApp.py --help

# %% [markdown]
# ## 2.2. Configuring processing parameters

# %% [markdown]
# The processing parameters for the **smallbaselineApp.py** are controlled through a configuration file. If no file is provided the default [smallbaselineApp.cfg](https://github.com/insarlab/MintPy/blob/master/mintpy/defaults/smallbaselineApp.cfg) configuration is used. We will create a custom config file with modified configuration parameters for this time-series analysis. Any options added to the custom config will override options set in the default config.

# %%
print("Do you wish to skip the template creation and data loading steps to work with a previously loaded dataset?")

skip_load_choice = asfn.select_parameter(['create a MintPy template and load data', 'skip template creation and data loading steps'])
display(skip_load_choice)
# Out:
# Do you wish to skip the template creation and data loading steps to work with a previously loaded dataset?
# RadioButtons(layout=Layout(min_width='800px'), options=('create a MintPy template and load data', 'skip templa…

# %%
load = 'skip' not in skip_load_choice.value

if load:
    config = f'''# vim: set filetype=cfg:
    mintpy.load.processor        = hyp3
    ##---------interferogram datasets:
    mintpy.load.unwFile          = {work_path}/*/*unw_phase*.tif
    mintpy.load.corFile          = {work_path}/*/*corr*.tif
    ##---------geometry datasets:
    mintpy.load.demFile          = {work_path}/*/*dem*.tif
    mintpy.load.incAngleFile     = {work_path}/*/*lv_theta*.tif
    mintpy.load.azAngleFile      = {work_path}/*/*lv_phi*.tif
    mintpy.load.waterMaskFile    = {work_path}/*/*water_mask*.tif
    '''

# %%
if load:
    ref_point_option = asfn.select_parameter(["Allow MintPy to determine a reference point", 
                                             "Define a reference point"])
    display(ref_point_option)

# %%
if load:
    is_float = False
    ref_pt_config = ''
    while not is_float:
        if 'Define' in ref_point_option.value:
            try:
                lat = float(input("Enter reference latitude"))
                lon = float(input("Enter reference longitude"))
                is_float = True
            except ValueError:
                print("Latitude and Longitude must be convertable to float")
                continue
            ref_pt_config = f'\nmintpy.reference.lalo        = {lat},{lon}'
        else:
            break

# %%
if load:
    ref_date_option = asfn.select_parameter(["Allow MintPy to determine reference date", 
                                             "Reference time-series to earliest date in stack"])

    display(ref_date_option)

# %%
if load:
    ref_date_config = ''
    if 'MintPy' in ref_date_option.value:
        ref_date_config = f'\nmintpy.reference.date       = auto'
    else:
        ref_date_config = f'\nmintpy.reference.date       = no'

# %% [markdown]
# **MintPy allows for multithreaded processing using Dask for interferogram inversion and topographic correction.**
#
# MintPy defaults to sequential processing.
# In general, multithreaded processing will be faster.
#
# If you opt to use multithreaded proccessing, be aware that Dask will use CPU cores on your compute instance, which may impact the processing speeds for scripts and other notebooks running at the same time.
#
# https://www.dask.org/
#
# Note: The following code cell may list more CPU cores than available if you are running this on a shared instance in a Jupyter Hub, such as OpenSARLab. In this case, if opting to use all available cores for Dask multi-threading, multiple Dask workers will be assigned to each CPU core. The code will still run and you will still see a speed improvement compared to sequential processing.

# %%
if load:
    cpu_count = os.cpu_count()

    print(f"You currently have access to {cpu_count} logical CPU cores")
    multithread_option = asfn.select_parameter(["Do not use multithreaded processing",
                                         f"Use all {cpu_count} available cores for multithreaded processing",
                                         "Use some of my available cores for multithreaded processing"])
    display(multithread_option)

# %%
if load:
    if 'Use all' in multithread_option.value:
        multithread_config = f'''\nmintpy.compute.cluster      = local
    mintpy.compute.numWorker    = {cpu_count}'''
    elif 'Use some' in multithread_option.value:
        valid_cpu_count = False
        worker_cores = 9999999999
        while not valid_cpu_count:
            try:
                worker_cores = int(input(f"Enter the number of CPU cores to use for multithreading (must be {cpu_count} or less)"))
            except ValueError:
                pass
            valid_cpu_count = worker_cores <= cpu_count
        multithread_config = f'''\nmintpy.compute.cluster      = local
    mintpy.compute.numWorker    = {worker_cores}'''
    else:
        multithread_config = ''

# %%
config_path = mint_path/f'{proj_name}.txt'

if load:
    updated_config = f'{config}{ref_pt_config}{ref_date_config}{multithread_config}'

    with open(config_path, 'w') as f:
        f.write(updated_config)
        print(f"config file path: {config_path}\n")

    with open(config_path, 'r') as f:
        for line in f.readlines():
            print(line)

# %% [markdown]
# # 3. Small Baseline Time Series Analysis
#
# **You can run every step in smallbaselineApp.py with one call, using the command in the cell below**
#
# **For the purposes of this tutorial, we will run each step separately**
#
# We will run the steps:
# - load_data
# - modify_network
# - reference_point
# - quick_overview
# - invert_network
# - correct_troposphere
# - correct_topography
# - residual_RMS
# - reference_date
# - velocity
# - google_earth
#
# Skipped steps include:
# - correct_unwrap_error
# - correct_LOD
# - correct_SET
# - deramp
# - hdfeos5
#
# Skipped steps will also be skipped if running the entire smallbaselineApp in the cell below.

# %%
# This runs every step

# !smallbaselineApp.py --work-dir {mint_path}  {config_path}

# %% [markdown]
# ## 3.1. Load Data
#
# **Run the `load_data` step**
#
# - If you get a missing 'Height' attribute error, you are missing a DEM, which is an available option when ordering HyP3 InSAR products

# %%
if load:
    # !smallbaselineApp.py $config_path --work-dir {mint_path} --dostep load_data

# %% [markdown]
# The output of the loading step is an "inputs" directory containing two HDF5 files:
# - ifgramStack.h5: This file contains 6 dataset cubes (e.g. unwrapped phase, coherence, connected components etc.) and multiple metadata.
# - geometryGeo.h5: This file contains geometrical datasets (e.g., incidence/azimuth angle, masks, etc.).

# %%
inputs_path = mint_path/'inputs'
# !ls $inputs_path
# Out:
# geometryGeo.h5	ifgramStack.h5	smallbaselineApp.cfg  tuscon.txt

# %% [markdown]
# <div class="alert alert-info">
# <b>info.py :</b>
# To get general infomation about a MintPy product, run info.py on the file.
# </div>

# %% [markdown]
# ## 3.2. Modify the Network
#
# **Run the `modify_network` step**
#
# - Identifies and excludes interferograms (i.e. affected by remaining coherence phase-unwrapping errors) before the network inversion

# %%
# !smallbaselineApp.py $config_path --work-dir {mint_path} --dostep modify_network
# Out:
# MintPy version 1.5.1, date 2023-01-03
# --RUN-at-2024-03-12 21:36:00.815353--
# Current directory: /home/jovyan/notebooks/SAR_Training/English/Master
# Run routine processing with smallbaselineApp.py on steps: ['modify_network']
# Remaining steps: ['reference_point', 'quick_overview', 'correct_unwrap_error', 'invert_network', 'correct_LOD', 'correct_SET', 'correct_troposphere', 'deramp', 'correct_topography', 'residual_RMS', 'reference_date', 'velocity', 'geocode', 'google_earth', 'hdfeos5']
# --------------------------------------------------
# Project name: tuscon
# Go to work directory: /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy
# read custom template file: /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/tuscon.txt
# update default template based on input custom template
# No new option value found, skip updating /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/smallbaselineApp.cfg
# copy smallbaselineApp.cfg to inputs   directory for backup.
# copy smallbaselineApp.cfg to pic      directory for backup.
# read default template file: /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/smallbaselineApp.cfg
#
#
# ******************** step - modify_network ********************
# Input data seems to be geocoded. Lookup file not needed.
# generate /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/waterMask.h5 from /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/inputs/geometryGeo.h5 for conveniency
# ['/home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/waterMask.h5'] exists and is newer than ['/home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/inputs/geometryGeo.h5'] --> skip.
#
# modify_network.py /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/inputs/ifgramStack.h5 -t /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/smallbaselineApp.cfg
# read options from template file: smallbaselineApp.cfg
# No lookup table (longitude or rangeCoord) found in files.
# No input option found to remove interferogram
# Keep all interferograms by enable --reset option
# --------------------------------------------------
# reset dataset 'dropIfgram' to True for all interferograms for file: /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/inputs/ifgramStack.h5
# All dropIfgram are already True, no need to reset.
#
# plot_network.py /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/inputs/ifgramStack.h5 -t /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/smallbaselineApp.cfg --nodisplay -d coherence -v 0.2 1.0
# ['/home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/network.pdf'] exists and is newer than ['/home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/inputs/ifgramStack.h5', '/home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/coherenceSpatialAvg.txt', '/home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/smallbaselineApp.cfg'] --> skip.
# Go back to directory: /home/jovyan/notebooks/SAR_Training/English/Master
#
# ################################################
#    Normal end of smallbaselineApp processing!
# ################################################
# Time used: 00 mins 0.9 secs

# %% [markdown]
# ## 3.3. Plot the interferogram network
#
# Running **plot_network.py** gives an overview of the network and the average coherence of the stack. The program creates multiple files as follows:
# - `ifgramStack_coherence_spatialAvg.txt`: Contains interferogram dates, average coherence temporal and spatial baseline separation.
# - `Network.pdf`: Displays the network of interferograms on time-baseline coordinates, colorcoded by avergae coherence of the interferograms.
# - `CoherenceMatrix.pdf` shows the avergae coherence pairs between all available pairs in the stack.

# %%
# %matplotlib inline
with asfn.work_dir(mint_path):
    scp_args = f'{inputs_path}/ifgramStack.h5 --cmap-vlist 0.2 0.7 1.0'
    plot_network.main(scp_args.split())
    plots = ['bperpHistory.pdf', 'coherenceHistory.pdf', 'coherenceMatrix.pdf', 'network.pdf']
    for p in plots:
        if (mint_path/p).exists():
            (mint_path/p).rename(f'{plot_path}/{p}')
# Out:
# read temporal/spatial baseline info from file: /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/inputs/ifgramStack.h5
# open ifgramStack file: ifgramStack.h5
# ['coherenceSpatialAvg.txt'] exists and is newer than ['/home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/inputs/ifgramStack.h5', 'waterMask.h5'] --> skip.
# coherenceSpatialAvg.txt already exists, read it directly
# number of acquisitions: 12
# number of interferograms: 38
# shift all perp baseline by -7.91864538192749 to zero mean for plotting
# --------------------------------------------------
# number of interferograms marked as drop: 0
# number of interferograms marked as keep: 38
# number of acquisitions marked as drop: 0
# max perpendicular baseline: 135.98 m
# max temporal      baseline: 48.0 days
# showing coherence
# data range: [0.8351, 0.9836]
# display range: (0.2, 1.0)
# showing ...

# %% [markdown]
# ## 3.4. Set the Reference Point
#
# **Run the `reference_point` step**
#
# The interferometric phase is a relative observation by nature. The phases of each unwrapped interferogram are relative with respect to an arbitrary pixel. Therfore, we need to reference all interferograms to a common reference pixel.
#
# The `reference_point` step selects a common reference pixel for the stack of interferograms. The default approach of MintPy is to choose a pixel with the highest spatial coherence in the stack. Other options include specifying the longitude and latitude of the desired reference pixel or the line and column number of the refence pixel.

# %%
# !smallbaselineApp.py $config_path --work-dir {mint_path} --dostep reference_point
# Out:
# MintPy version 1.5.1, date 2023-01-03
# --RUN-at-2024-03-12 21:36:14.855283--
# Current directory: /home/jovyan/notebooks/SAR_Training/English/Master
# Run routine processing with smallbaselineApp.py on steps: ['reference_point']
# Remaining steps: ['quick_overview', 'correct_unwrap_error', 'invert_network', 'correct_LOD', 'correct_SET', 'correct_troposphere', 'deramp', 'correct_topography', 'residual_RMS', 'reference_date', 'velocity', 'geocode', 'google_earth', 'hdfeos5']
# --------------------------------------------------
# Project name: tuscon
# Go to work directory: /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy
# read custom template file: /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/tuscon.txt
# update default template based on input custom template
# No new option value found, skip updating /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/smallbaselineApp.cfg
# read default template file: /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/smallbaselineApp.cfg
#
#
# ******************** step - reference_point ********************
# Input data seems to be geocoded. Lookup file not needed.
#
# generate_mask.py /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/inputs/ifgramStack.h5 --nonzero -o /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/maskConnComp.h5 --update
# input ifgramStack file: /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/inputs/ifgramStack.h5
# --------------------------------------------------
# update mode: ON
# 1) output file /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/maskConnComp.h5 already exists.
# 2) output file is newer than input dataset: unwrapPhase.
# run or skip: skip.
#
# temporal_average.py /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/inputs/ifgramStack.h5 --dataset coherence -o /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/avgSpatialCoh.h5 --update
# --------------------------------------------------
# update mode: ON
# 1) output file /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/avgSpatialCoh.h5 already exists.
# 2) output file is newer than input dataset: coherence.
# run or skip: skip.
# Input data seems to be geocoded. Lookup file not needed.
#
# reference_point.py /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/inputs/ifgramStack.h5 -t /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/smallbaselineApp.cfg -c /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/avgSpatialCoh.h5
# --------------------------------------------------
# reading reference info from template: /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/smallbaselineApp.cfg
# input reference point in lat/lon: (34.32, -111.74159)
# input reference point in y/x: (525, 1047)
# mask: maskConnComp.h5
# --------------------------------------------------
# SAME reference pixel is already selected/saved in file, skip updating.
# Go back to directory: /home/jovyan/notebooks/SAR_Training/English/Master
#
# ################################################
#    Normal end of smallbaselineApp processing!
# ################################################
# Time used: 00 mins 0.4 secs

# %% [markdown]
# **Running the "reference_step" adds additional attributes "REF_X, REF_Y" and "REF_LON, REF_LAT" to the `ifgramStack.h5` file. To see the attributes of the file run `info.py`**

# %%
# !info.py $inputs_path/ifgramStack.h5 | egrep 'REF_'
# Out:
#   REF_LAT                            34.31966441234754
#   REF_LON                            -111.74117966662918
#   REF_X                              1047
#   REF_Y                              525

# %% [markdown]
# ## 3.5. Run a Quick Overview
#
# **Run the `quick_overview` step**
#
# - Assess possible groud deformation using the velocity from traditional interferogram stacking
#     - *reference: Zebker et al. (1997, JGR)*
# - Assess distribution of phase unwrapping error from the number of interferogram triplets with non-zero integer ambiguity of closure phase
#     - *reference: T_int in Yunjun et al. (2019, CAGEO). Related to section 3.2, equation (8-9) and Fig. 3d-e.*

# %%
# !smallbaselineApp.py $config_path --work-dir {mint_path} --dostep quick_overview
# Out:
# MintPy version 1.5.1, date 2023-01-03
# --RUN-at-2024-03-12 21:36:23.029499--
# Current directory: /home/jovyan/notebooks/SAR_Training/English/Master
# Run routine processing with smallbaselineApp.py on steps: ['quick_overview']
# Remaining steps: ['correct_unwrap_error', 'invert_network', 'correct_LOD', 'correct_SET', 'correct_troposphere', 'deramp', 'correct_topography', 'residual_RMS', 'reference_date', 'velocity', 'geocode', 'google_earth', 'hdfeos5']
# --------------------------------------------------
# Project name: tuscon
# Go to work directory: /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy
# read custom template file: /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/tuscon.txt
# update default template based on input custom template
# No new option value found, skip updating /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/smallbaselineApp.cfg
# read default template file: /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/smallbaselineApp.cfg
#
#
# ******************** step - quick_overview ********************
# Input data seems to be geocoded. Lookup file not needed.
#
# temporal_average.py /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/inputs/ifgramStack.h5 --dataset unwrapPhase -o /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/avgPhaseVelocity.h5 --update
# --------------------------------------------------
# update mode: ON
# 1) output file /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/avgPhaseVelocity.h5 already exists.
# 2) output file is newer than input dataset: unwrapPhase.
# run or skip: skip.
#
# unwrap_error_phase_closure.py /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/inputs/ifgramStack.h5 --water-mask /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/waterMask.h5 --action calculate --update
# update mode: ON
# 1) output file "/home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/numTriNonzeroIntAmbiguity.h5" already exists
# 2) output file is newer than input dataset
# 3) all key configurations are the same: ['REF_Y', 'REF_X']
# run or skip: skip.
# time used: 00 mins 0.0 secs
# Done.
# Go back to directory: /home/jovyan/notebooks/SAR_Training/English/Master
#
# ################################################
#    Normal end of smallbaselineApp processing!
# ################################################
# Time used: 00 mins 0.9 secs

# %% [markdown]
# ## 3.6. Inverting the Small Baseline network
#
# **Run the `invert_network` step**
#
# - Invert the network of differential unwrapped interferograms to estimate the time-series of unwrapped phase with respect to a reference acquisition date
# - By default mintpy selects the first acquisition
# - The estimated time-series is converted to distance change from radar to target and is provided in meters.

# %%
ifgram_path = mint_path/"inputs/ifgramStack.h5"

# %%
# !smallbaselineApp.py $config_path --work-dir {mint_path} --dostep invert_network
# Out:
# MintPy version 1.5.1, date 2023-01-03
# --RUN-at-2024-03-12 21:36:30.604819--
# Current directory: /home/jovyan/notebooks/SAR_Training/English/Master
# Run routine processing with smallbaselineApp.py on steps: ['invert_network']
# Remaining steps: ['correct_LOD', 'correct_SET', 'correct_troposphere', 'deramp', 'correct_topography', 'residual_RMS', 'reference_date', 'velocity', 'geocode', 'google_earth', 'hdfeos5']
# --------------------------------------------------
# Project name: tuscon
# Go to work directory: /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy
# read custom template file: /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/tuscon.txt
# update default template based on input custom template
# No new option value found, skip updating /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/smallbaselineApp.cfg
# read default template file: /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/smallbaselineApp.cfg
#
#
# ******************** step - invert_network ********************
# Input data seems to be geocoded. Lookup file not needed.
#
# ifgram_inversion.py /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/inputs/ifgramStack.h5 -t /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/smallbaselineApp.cfg --update
# read input option from template file: /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/smallbaselineApp.cfg
# use dataset "unwrapPhase" by default
# --------------------------------------------------
# update mode: ON
# 1) output files already exist: ['timeseries.h5', 'temporalCoherence.h5', 'numInvIfgram.h5'].
# 2) output dataset is newer than input dataset: unwrapPhase.
# 3) all key configuration parameters are the same: ['obsDatasetName', 'numIfgram', 'weightFunc', 'maskDataset', 'maskThreshold', 'minRedundancy', 'minNormVelocity'].
# run or skip: skip.
# Input data seems to be geocoded. Lookup file not needed.
#
# generate_mask.py /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/temporalCoherence.h5 -m 0.7 -o /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/maskTempCoh.h5
# update mode: ON
# run or skip: run
# input temporalCoherence file: /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/temporalCoherence.h5
# read /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/temporalCoherence.h5
# create initial mask with the same size as the input file and all = 1
# all pixels with nan value = 0
# exclude pixels with value < 0.7
# delete exsited file: /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/maskTempCoh.h5
# create HDF5 file: /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/maskTempCoh.h5 with w mode
# create dataset /mask of bool       in size of (1003, 1711)         with compression=None
# finished writing to /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/maskTempCoh.h5
# time used: 00 mins 0.1 secs.
# number of reliable pixels: 922284
# Go back to directory: /home/jovyan/notebooks/SAR_Training/English/Master
#
# ################################################
#    Normal end of smallbaselineApp processing!
# ################################################
# Time used: 00 mins 1.1 secs

# %% [markdown]
# ## 3.7. Correct for Tropospheric Propagation Delays (Optional)
#
#
# <div class="alert alert-warning">
# <font face="Calibri" size="5"><b><font color='rgba(200,0,0,0.2)'> <u>CDS is preparing to launch a new website and current service is impacted</u></font></b></font>
# <br/>
# <font face="Calibri" size="4">   February 14, 2024
# </font>
# <br/>
# <font face="Calibri" size="3"><a href="https://forum.ecmwf.int/t/a-new-cds-soon-to-be-launched-expect-some-disruptions/1607">https://forum.ecmwf.int/t/a-new-cds-soon-to-be-launched-expect-some-disruptions/1607</a>
#     <br/><br/>
# <i><b>Expect:</b>
#     <ul>
# <li>longer queues</li>
# <li>requests being cancelled</li>
# <li>temporary closure of queues</li>
# <li>requests failing with unusual error messages</li>
# <li>catalogue temporarily offline</li>
# </font>
# </div>
#
# **Run the `correct_troposphere` step**
#
# - Uses ECMWF [ERA5 climate reanalysis pressure data](https://cds.climate.copernicus.eu/cdsapp#!/search?type=dataset&keywords=((%20%22Product%20type:%20Reanalysis%22%20)%20AND%20(%20%22Provider:%20Copernicus%20C3S%22%20))&text=pressure)
# - CDS limits ECMWF archive requests to 50, so your requests may be queued until there is space.
#     - https://cds.climate.copernicus.eu/live/queue

# %%
if load:
    tropo_choice = asfn.select_parameter(["Perform Tropospheric Correction Step",
                                          "Skip Tropospheric Correction Step",
                                          "Delete Outputs of a Previous (possibly interrupted) Troposheric Correction and Rerun",
                                          "Delete Outputs of a Previous Troposheric Correction and Skip Troposheric Correction Now"])
    display(tropo_choice)
else:
    tropo_files = list(mint_path.glob('*ERA5*.h5'))
    if 0 < len(tropo_files) < 3:
        # some but not all tropo corrected HDF5s are present and we should delete outputs rerun troposheric correction
        tropo_choice = "Delete and Rerun"
    elif len(tropo_files) == 0:
        # tropospheric correction was not performed
        tropo_choice = "Skip"
    else:
        # tropospheric correction was performed and all necessary HDF5 files are present
        tropo_choice = "Done"

# %%
def set_troposhperic_correction_mintpy(config_path, method):
    config_path = Path(config_path)
    with open(config_path, 'r') as f:
        config = f.readlines()    
    config_update = config
    
    for i, l in enumerate(config):
        no_comment = l.split("#")[0]
        present = False
        if "mintpy.troposphericDelay.method=" in "".join(no_comment.split()):
            config_update[i] = f"mintpy.troposphericDelay.method = {method}"
            present = True
            break     
    if not present:
        config_update.append(f"\nmintpy.troposphericDelay.method = {method}")

    config_str = ""
    for l in config_update:
        config_str = f"{config_str}{l}"
    
    with open(config_path, 'w') as f:
        f.write(config_str)

# %%
if type(tropo_choice) != str:
    tropo_choice = tropo_choice.value

correct_tropo = "Perform" in tropo_choice or "Rerun" in tropo_choice or "Done" in tropo_choice

era5_path = mint_path/"ERA5"
timeseries_era5_path = mint_path/"timeseries_ERA5.h5"
inputs_era5_path = mint_path/"inputs/ERA5.h5"

if "Delete" in tropo_choice:
    for f in [timeseries_era5_path, inputs_era5_path]:
        try:
            f.unlink()
        except FileNotFoundError:
            pass
    try:
        shutil.rmtree(era5_path)
    except FileNotFoundError:
        pass

if correct_tropo and "Done" not in tropo_choice:
    set_troposhperic_correction_mintpy(config_path, "pyaps")
    # !smallbaselineApp.py $config_path --work-dir {mint_path} --dostep load_data
    # !smallbaselineApp.py $config_path --work-dir {mint_path} --dostep correct_troposphere
elif not correct_tropo:
    set_troposhperic_correction_mintpy(config_path, "no")
    # !smallbaselineApp.py $config_path --work-dir {mint_path} --dostep load_data
# Out:
# MintPy version 1.5.1, date 2023-01-03
# --RUN-at-2024-03-12 21:37:02.206995--
# Current directory: /home/jovyan/notebooks/SAR_Training/English/Master
# Run routine processing with smallbaselineApp.py on steps: ['load_data']
# Remaining steps: ['modify_network', 'reference_point', 'quick_overview', 'correct_unwrap_error', 'invert_network', 'correct_LOD', 'correct_SET', 'correct_troposphere', 'deramp', 'correct_topography', 'residual_RMS', 'reference_date', 'velocity', 'geocode', 'google_earth', 'hdfeos5']
# --------------------------------------------------
# Project name: tuscon
# Go to work directory: /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy
# read custom template file: /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/tuscon.txt
# update default template based on input custom template
# No new option value found, skip updating /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/smallbaselineApp.cfg
# copy tuscon.txt           to inputs   directory for backup.
# copy tuscon.txt           to pic      directory for backup.
# read default template file: /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/smallbaselineApp.cfg
#
#
# ******************** step - load_data ********************
#
# load_data.py --template /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/smallbaselineApp.cfg /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/tuscon.txt --project tuscon
# processor : hyp3
# SAR platform/sensor : unknown from project name "tuscon"
# --------------------------------------------------
# prepare metadata files for hyp3 products
# prep_hyp3.py "/home/jovyan/notebooks/SAR_Training/English/Master/tuscon/*/*unw_phase*.tif"
# prep_hyp3.py "/home/jovyan/notebooks/SAR_Training/English/Master/tuscon/*/*corr*.tif"
# prep_hyp3.py "/home/jovyan/notebooks/SAR_Training/English/Master/tuscon/*/*dem*.tif"
# prep_hyp3.py "/home/jovyan/notebooks/SAR_Training/English/Master/tuscon/*/*lv_theta*.tif"
# prep_hyp3.py "/home/jovyan/notebooks/SAR_Training/English/Master/tuscon/*/*lv_phi*.tif"
# prep_hyp3.py "/home/jovyan/notebooks/SAR_Training/English/Master/tuscon/*/*water_mask*.tif"
# --------------------------------------------------
# updateMode : True
# compression: None
# multilook x/ystep: 1/1
# multilook method : nearest
# --------------------------------------------------
# searching geometry files info
# input data files:
# height          : /home/jovyan/notebooks/SAR_Training/English/Master/tuscon/S1AA_20220110T132756_20220122T132756_VVP012_INT80_G_ueF_DB6D/S1AA_20220110T132756_20220122T132756_VVP012_INT80_G_ueF_DB6D_dem_clip_clip.tif
# incidenceAngle  : /home/jovyan/notebooks/SAR_Training/English/Master/tuscon/S1AA_20220110T132756_20220122T132756_VVP012_INT80_G_ueF_DB6D/S1AA_20220110T132756_20220122T132756_VVP012_INT80_G_ueF_DB6D_lv_theta_clip_clip.tif
# azimuthAngle    : /home/jovyan/notebooks/SAR_Training/English/Master/tuscon/S1AA_20220110T132756_20220122T132756_VVP012_INT80_G_ueF_DB6D/S1AA_20220110T132756_20220122T132756_VVP012_INT80_G_ueF_DB6D_lv_phi_clip_clip.tif
# waterMask       : /home/jovyan/notebooks/SAR_Training/English/Master/tuscon/S1AA_20220110T132756_20220122T132756_VVP012_INT80_G_ueF_DB6D/S1AA_20220110T132756_20220122T132756_VVP012_INT80_G_ueF_DB6D_water_mask_clip_clip.tif
# All datasets exists in file geometryGeo.h5 with same size as required, no need to re-load.
# --------------------------------------------------
# searching interferogram pairs info
# input data files:
# unwrapPhase     : /home/jovyan/notebooks/SAR_Training/English/Master/tuscon/*/*unw_phase*.tif
# coherence       : /home/jovyan/notebooks/SAR_Training/English/Master/tuscon/*/*corr*.tif
# number of unwrapPhase     : 38
# number of coherence       : 38
# All date12   exists in file ifgramStack.h5 with same size as required, no need to re-load.
# --------------------------------------------------
# searching ionosphere pairs info
# input data files:
# WARNING: No data files found for the required dataset: ['unwrapPhase']! Skip loading for ionosphere stack.
# --------------------------------------------------
# searching offset pairs info
# input data files:
# WARNING: No data files found for the required dataset: ['rangeOffset', 'azimuthOffset']! Skip loading for offset stack.
# time used: 00 mins 0.5 secs.
#
# No lookup table (longitude or rangeCoord) found in files.
# Input data seems to be geocoded. Lookup file not needed.
# Loaded dataset are processed by InSAR software: hyp3
# Loaded dataset are in GEO coordinates
# Interferogram Stack: /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/inputs/ifgramStack.h5
# Geometry      File : /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/inputs/geometryGeo.h5
# Lookup Table  File : None
# --------------------------------------------------
# updating metadata based on custom template file tuscon.txt for file: ifgramStack.h5
# updating metadata based on custom template file tuscon.txt for file: geometryGeo.h5
# Go back to directory: /home/jovyan/notebooks/SAR_Training/English/Master
#
# ################################################
#    Normal end of smallbaselineApp processing!
# ################################################
# Time used: 00 mins 0.6 secs

# %%
# !smallbaselineApp.py $config_path --work-dir {mint_path} --dostep correct_troposphere
# Out:
# MintPy version 1.5.1, date 2023-01-03
# --RUN-at-2024-03-12 21:37:06.892371--
# Current directory: /home/jovyan/notebooks/SAR_Training/English/Master
# Run routine processing with smallbaselineApp.py on steps: ['correct_troposphere']
# Remaining steps: ['deramp', 'correct_topography', 'residual_RMS', 'reference_date', 'velocity', 'geocode', 'google_earth', 'hdfeos5']
# --------------------------------------------------
# Project name: tuscon
# Go to work directory: /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy
# read custom template file: /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/tuscon.txt
# update default template based on input custom template
# No new option value found, skip updating /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/smallbaselineApp.cfg
# read default template file: /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/smallbaselineApp.cfg
#
#
# ******************** step - correct_troposphere ********************
# Input data seems to be geocoded. Lookup file not needed.
# No tropospheric delay correction.
# Go back to directory: /home/jovyan/notebooks/SAR_Training/English/Master
#
# ################################################
#    Normal end of smallbaselineApp processing!
# ################################################
# Time used: 00 mins 0.1 secs

# %% [markdown]
# ## 3.8. Correct for DEM Errors
#
# **Run the `correct_topography` step**

# %%
# !smallbaselineApp.py $config_path --work-dir {mint_path} --dostep correct_topography
# Out:
# MintPy version 1.5.1, date 2023-01-03
# --RUN-at-2024-03-12 21:37:10.759686--
# Current directory: /home/jovyan/notebooks/SAR_Training/English/Master
# Run routine processing with smallbaselineApp.py on steps: ['correct_topography']
# Remaining steps: ['residual_RMS', 'reference_date', 'velocity', 'geocode', 'google_earth', 'hdfeos5']
# --------------------------------------------------
# Project name: tuscon
# Go to work directory: /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy
# read custom template file: /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/tuscon.txt
# update default template based on input custom template
# No new option value found, skip updating /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/smallbaselineApp.cfg
# read default template file: /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/smallbaselineApp.cfg
#
#
# ******************** step - correct_topography ********************
# Input data seems to be geocoded. Lookup file not needed.
#
# dem_error.py /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/timeseries.h5 -t /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/smallbaselineApp.cfg -o /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/timeseries_demErr.h5 --update -g /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/inputs/geometryGeo.h5
# read options from template file: smallbaselineApp.cfg
# --------------------------------------------------
# update mode: ON
# 1) output file /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/timeseries_demErr.h5 already exists.
# 2) output file is newer than input file: ['/home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/timeseries.h5', '/home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/inputs/geometryGeo.h5'].
# 3) NOT all key configuration parameters are the same:['polyOrder', 'phaseVelocity', 'stepFuncDate', 'excludeDate']
# run or skip: run.
# save the original settings of ['OMP_NUM_THREADS', 'OPENBLAS_NUM_THREADS', 'MKL_NUM_THREADS', 'NUMEXPR_NUM_THREADS', 'VECLIB_MAXIMUM_THREADS']
# set OMP_NUM_THREADS = 1
# set OPENBLAS_NUM_THREADS = 1
# set MKL_NUM_THREADS = 1
# set NUMEXPR_NUM_THREADS = 1
# set VECLIB_MAXIMUM_THREADS = 1
# open timeseries file: timeseries.h5
# exclude the following dates for DEM error estimation: (2)
# ['20220323', '20220404']
# --------------------------------------------------------------------------------
# correct topographic phase residual (DEM error) (Fattahi & Amelung, 2013, IEEE-TGRS)
# ordinal least squares (OLS) inversion with L2-norm minimization on: phase
# temporal deformation model: polynomial order = 2
# --------------------------------------------------------------------------------
# add/update the following configuration metadata to file:
# ['polyOrder', 'phaseVelocity', 'stepFuncDate', 'excludeDate']
# --------------------------------------------------
# create HDF5 file: demErr.h5 with w mode
# create dataset  : dem of <class 'numpy.float32'>   in size of (1003, 1711)         with compression = None
# close  HDF5 file: demErr.h5
# --------------------------------------------------
# grab dataset structure from ref_file: /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/timeseries.h5
# create HDF5 file: /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/timeseries_demErr.h5 with w mode
# create dataset  : bperp      of float32                   in size of (12,)                with compression = None
# create dataset  : date       of |S8                       in size of (12,)                with compression = None
# create dataset  : timeseries of float32                   in size of (12, 1003, 1711)     with compression = None
# close  HDF5 file: /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/timeseries_demErr.h5
# --------------------------------------------------
# grab dataset structure from ref_file: /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/timeseries.h5
# create HDF5 file: /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/timeseriesResidual.h5 with w mode
# create dataset  : bperp      of float32                   in size of (12,)                with compression = None
# create dataset  : date       of |S8                       in size of (12,)                with compression = None
# create dataset  : timeseries of float32                   in size of (12, 1003, 1711)     with compression = None
# close  HDF5 file: /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/timeseriesResidual.h5
#
#
# ------- start parallel processing using Dask -------
# input Dask cluster type: local
# initiate Dask cluster
# split patch into 32 sub boxes in x direction for workers to process
# scale Dask cluster to 32 workers
# initiate Dask client
# submit a job to the worker for sub box 0: [0, 0, 54, 1003]
# submit a job to the worker for sub box 1: [54, 0, 108, 1003]
# submit a job to the worker for sub box 2: [108, 0, 162, 1003]
# submit a job to the worker for sub box 3: [162, 0, 216, 1003]
# submit a job to the worker for sub box 4: [216, 0, 270, 1003]
# submit a job to the worker for sub box 5: [270, 0, 324, 1003]
# submit a job to the worker for sub box 6: [324, 0, 378, 1003]
# submit a job to the worker for sub box 7: [378, 0, 432, 1003]
# submit a job to the worker for sub box 8: [432, 0, 486, 1003]
# submit a job to the worker for sub box 9: [486, 0, 540, 1003]
# submit a job to the worker for sub box 10: [540, 0, 594, 1003]
# submit a job to the worker for sub box 11: [594, 0, 648, 1003]
# submit a job to the worker for sub box 12: [648, 0, 702, 1003]
# submit a job to the worker for sub box 13: [702, 0, 756, 1003]
# submit a job to the worker for sub box 14: [756, 0, 810, 1003]
# submit a job to the worker for sub box 15: [810, 0, 864, 1003]
# submit a job to the worker for sub box 16: [864, 0, 918, 1003]
# submit a job to the worker for sub box 17: [918, 0, 972, 1003]
# submit a job to the worker for sub box 18: [972, 0, 1026, 1003]
# submit a job to the worker for sub box 19: [1026, 0, 1080, 1003]
# submit a job to the worker for sub box 20: [1080, 0, 1134, 1003]
# submit a job to the worker for sub box 21: [1134, 0, 1188, 1003]
# submit a job to the worker for sub box 22: [1188, 0, 1242, 1003]
# submit a job to the worker for sub box 23: [1242, 0, 1296, 1003]
# submit a job to the worker for sub box 24: [1296, 0, 1350, 1003]
# submit a job to the worker for sub box 25: [1350, 0, 1404, 1003]
# submit a job to the worker for sub box 26: [1404, 0, 1458, 1003]
# submit a job to the worker for sub box 27: [1458, 0, 1512, 1003]
# submit a job to the worker for sub box 28: [1512, 0, 1566, 1003]
# submit a job to the worker for sub box 29: [1566, 0, 1620, 1003]
# submit a job to the worker for sub box 30: [1620, 0, 1674, 1003]
# submit a job to the worker for sub box 31: [1674, 0, 1711, 1003]
# open geometry file: geometryGeo.h5
# open geometry file: geometryGeo.h5
# open geometry file: geometryGeo.h5
# read 2D incidenceAngle, slantRangeDistance from geometry file: geometryGeo.h5
# read 2D incidenceAngle, slantRangeDistance from geometry file: geometryGeo.h5
# read 2D incidenceAngle, slantRangeDistance from geometry file: geometryGeo.h5
# open geometry file: geometryGeo.h5
# open geometry file: geometryGeo.h5
# open geometry file: geometryGeo.h5
# open geometry file: geometryGeo.h5
# read 2D incidenceAngle, slantRangeDistance from geometry file: geometryGeo.h5
# read 2D incidenceAngle, slantRangeDistance from geometry file: geometryGeo.h5
# read 2D incidenceAngle, slantRangeDistance from geometry file: geometryGeo.h5
# read mean bperp from timeseries file
# skip pixels with ZERO in ALL acquisitions
# read 2D incidenceAngle, slantRangeDistance from geometry file: geometryGeo.h5
# skip pixels with NaN  in ANY acquisitions
# read mean bperp from timeseries file
# skip pixels with ZERO in ALL acquisitions
# open geometry file: geometryGeo.h5
# skip pixels with ZERO temporal coherence
# skip pixels with NaN  in ANY acquisitions
# open geometry file: geometryGeo.h5
# read mean bperp from timeseries file
# skip pixels with ZERO in ALL acquisitions
# skip pixels with ZERO temporal coherence
# skip pixels with NaN  in ANY acquisitions
# skip pixels with ZERO temporal coherence
# read mean bperp from timeseries file
# skip pixels with ZERO in ALL acquisitions
# read 2D incidenceAngle, slantRangeDistance from geometry file: geometryGeo.h5
# read mean bperp from timeseries file
# skip pixels with ZERO in ALL acquisitions
# skip pixels with NaN  in ANY acquisitions
# skip pixels with NaN  in ANY acquisitions
# read 2D incidenceAngle, slantRangeDistance from geometry file: geometryGeo.h5
# skip pixels with ZERO temporal coherence
# skip pixels with ZERO temporal coherence
# skip pixels with ZERO / NaN value in incidenceAngle / slantRangeDistance
# read mean bperp from timeseries file
# number of pixels to invert: 31426 out of 54162 (58.0%)
# estimating DEM error pixel-wisely ...
# open geometry file: geometryGeo.h5
# skip pixels with ZERO in ALL acquisitions
# read mean bperp from timeseries file
# skip pixels with ZERO in ALL acquisitions
# skip pixels with NaN  in ANY acquisitions
# skip pixels with NaN  in ANY acquisitions
# skip pixels with ZERO temporal coherence
# skip pixels with ZERO temporal coherence
# skip pixels with ZERO / NaN value in incidenceAngle / slantRangeDistance
# number of pixels to invert: 31829 out of 54162 (58.8%)
# estimating DEM error pixel-wisely ...
# open geometry file: geometryGeo.h5
# read mean bperp from timeseries file
# skip pixels with ZERO in ALL acquisitions
# open geometry file: geometryGeo.h5
# open geometry file: geometryGeo.h5
# skip pixels with ZERO / NaN value in incidenceAngle / slantRangeDistance
# read 2D incidenceAngle, slantRangeDistance from geometry file: geometryGeo.h5
# number of pixels to invert: 30606 out of 54162 (56.5%)
# estimating DEM error pixel-wisely ...
# skip pixels with NaN  in ANY acquisitions
# read 2D incidenceAngle, slantRangeDistance from geometry file: geometryGeo.h5
# read mean bperp from timeseries file
# skip pixels with ZERO in ALL acquisitions
# skip pixels with ZERO temporal coherence
# read 2D incidenceAngle, slantRangeDistance from geometry file: geometryGeo.h5
# read 2D incidenceAngle, slantRangeDistance from geometry file: geometryGeo.h5
# skip pixels with ZERO / NaN value in incidenceAngle / slantRangeDistance
# skip pixels with NaN  in ANY acquisitions
# number of pixels to invert: 32249 out of 54162 (59.5%)
# estimating DEM error pixel-wisely ...
# skip pixels with ZERO temporal coherence
# skip pixels with ZERO / NaN value in incidenceAngle / slantRangeDistance
# skip pixels with ZERO / NaN value in incidenceAngle / slantRangeDistance
# number of pixels to invert: 33053 out of 54162 (61.0%)
# estimating DEM error pixel-wisely ...
# number of pixels to invert: 31017 out of 54162 (57.3%)
# estimating DEM error pixel-wisely ...
# open geometry file: geometryGeo.h5
# open geometry file: geometryGeo.h5
# open geometry file: geometryGeo.h5
# open geometry file: geometryGeo.h5
# open geometry file: geometryGeo.h5
# open geometry file: geometryGeo.h5
# open geometry file: geometryGeo.h5
# skip pixels with ZERO / NaN value in incidenceAngle / slantRangeDistance
# number of pixels to invert: 30800 out of 54162 (56.9%)
# estimating DEM error pixel-wisely ...
# read 2D incidenceAngle, slantRangeDistance from geometry file: geometryGeo.h5
# skip pixels with ZERO / NaN value in incidenceAngle / slantRangeDistance
# read 2D incidenceAngle, slantRangeDistance from geometry file: geometryGeo.h5
# number of pixels to invert: 28952 out of 54162 (53.5%)
# estimating DEM error pixel-wisely ...
# read 2D incidenceAngle, slantRangeDistance from geometry file: geometryGeo.h5
# read mean bperp from timeseries file
# open geometry file: geometryGeo.h5
# read 2D incidenceAngle, slantRangeDistance from geometry file: geometryGeo.h5
# skip pixels with ZERO in ALL acquisitions
# read 2D incidenceAngle, slantRangeDistance from geometry file: geometryGeo.h5
# read mean bperp from timeseries file
# skip pixels with ZERO in ALL acquisitions
# open geometry file: geometryGeo.h5
# read 2D incidenceAngle, slantRangeDistance from geometry file: geometryGeo.h5
# open geometry file: geometryGeo.h5
# skip pixels with NaN  in ANY acquisitions
# read mean bperp from timeseries file
# read mean bperp from timeseries file
# skip pixels with ZERO in ALL acquisitions
# skip pixels with ZERO in ALL acquisitions
# read 2D incidenceAngle, slantRangeDistance from geometry file: geometryGeo.h5
# open geometry file: geometryGeo.h5
# skip pixels with NaN  in ANY acquisitions
# skip pixels with ZERO / NaN value in incidenceAngle / slantRangeDistance
# skip pixels with ZERO temporal coherence
# number of pixels to invert: 29586 out of 54162 (54.6%)
# estimating DEM error pixel-wisely ...
# skip pixels with ZERO temporal coherence
# skip pixels with NaN  in ANY acquisitions
# read 2D incidenceAngle, slantRangeDistance from geometry file: geometryGeo.h5
# skip pixels with NaN  in ANY acquisitions
# skip pixels with ZERO temporal coherence
# read 2D incidenceAngle, slantRangeDistance from geometry file: geometryGeo.h5
# open geometry file: geometryGeo.h5
# read 2D incidenceAngle, slantRangeDistance from geometry file: geometryGeo.h5
# open geometry file: geometryGeo.h5
# skip pixels with ZERO temporal coherence
# read 2D incidenceAngle, slantRangeDistance from geometry file: geometryGeo.h5
# open geometry file: geometryGeo.h5
# read 2D incidenceAngle, slantRangeDistance from geometry file: geometryGeo.h5
# read 2D incidenceAngle, slantRangeDistance from geometry file: geometryGeo.h5
# read mean bperp from timeseries file
# skip pixels with ZERO in ALL acquisitions
# read mean bperp from timeseries file
# read mean bperp from timeseries file
# skip pixels with ZERO in ALL acquisitions
# skip pixels with ZERO in ALL acquisitions
# open geometry file: geometryGeo.h5
# read mean bperp from timeseries file
# skip pixels with ZERO in ALL acquisitions
# skip pixels with NaN  in ANY acquisitions
# skip pixels with ZERO temporal coherence
# read 2D incidenceAngle, slantRangeDistance from geometry file: geometryGeo.h5
# skip pixels with NaN  in ANY acquisitions
# skip pixels with NaN  in ANY acquisitions
# skip pixels with ZERO temporal coherence
# skip pixels with ZERO / NaN value in incidenceAngle / slantRangeDistance
# number of pixels to invert: 24863 out of 54162 (45.9%)
# skip pixels with NaN  in ANY acquisitions
# estimating DEM error pixel-wisely ...
# skip pixels with ZERO temporal coherence
# open geometry file: geometryGeo.h5
# skip pixels with ZERO temporal coherence
# read mean bperp from timeseries file
# read mean bperp from timeseries file
# skip pixels with ZERO in ALL acquisitions
# skip pixels with ZERO in ALL acquisitions
# skip pixels with ZERO / NaN value in incidenceAngle / slantRangeDistance
# number of pixels to invert: 28311 out of 54162 (52.3%)
# estimating DEM error pixel-wisely ...
# skip pixels with NaN  in ANY acquisitions
# read mean bperp from timeseries file
# skip pixels with NaN  in ANY acquisitions
# read mean bperp from timeseries file
# skip pixels with ZERO temporal coherence
# skip pixels with ZERO in ALL acquisitions
# skip pixels with ZERO in ALL acquisitions
# skip pixels with ZERO temporal coherence
# read 2D incidenceAngle, slantRangeDistance from geometry file: geometryGeo.h5
# read 2D incidenceAngle, slantRangeDistance from geometry file: geometryGeo.h5
# skip pixels with NaN  in ANY acquisitions
# skip pixels with ZERO / NaN value in incidenceAngle / slantRangeDistance
# skip pixels with ZERO temporal coherence
# skip pixels with ZERO / NaN value in incidenceAngle / slantRangeDistance
# number of pixels to invert: 30196 out of 54162 (55.8%)
# number of pixels to invert: 29364 out of 54162 (54.2%)
# estimating DEM error pixel-wisely ...
# estimating DEM error pixel-wisely ...
# open geometry file: geometryGeo.h5
# open geometry file: geometryGeo.h5
# read mean bperp from timeseries file
# skip pixels with ZERO in ALL acquisitions
# skip pixels with NaN  in ANY acquisitions
# read mean bperp from timeseries file
# skip pixels with ZERO in ALL acquisitions
# read mean bperp from timeseries file
# skip pixels with ZERO temporal coherence
# skip pixels with ZERO in ALL acquisitions
# skip pixels with ZERO / NaN value in incidenceAngle / slantRangeDistance
# number of pixels to invert: 24427 out of 54162 (45.1%)
# estimating DEM error pixel-wisely ...
# skip pixels with NaN  in ANY acquisitions
# read mean bperp from timeseries file
# read 2D incidenceAngle, slantRangeDistance from geometry file: geometryGeo.h5
# skip pixels with ZERO in ALL acquisitions
# skip pixels with ZERO temporal coherence
# read mean bperp from timeseries file
# skip pixels with ZERO in ALL acquisitions
# skip pixels with NaN  in ANY acquisitions
# skip pixels with NaN  in ANY acquisitions
# skip pixels with ZERO temporal coherence
# skip pixels with ZERO / NaN value in incidenceAngle / slantRangeDistance
# number of pixels to invert: 32646 out of 54162 (60.3%)
# estimating DEM error pixel-wisely ...
# skip pixels with NaN  in ANY acquisitions
# skip pixels with NaN  in ANY acquisitions
# skip pixels with ZERO temporal coherence
# read mean bperp from timeseries file
# skip pixels with ZERO in ALL acquisitions
# skip pixels with ZERO / NaN value in incidenceAngle / slantRangeDistance
# skip pixels with ZERO temporal coherence
# number of pixels to invert: 31698 out of 54162 (58.5%)
# estimating DEM error pixel-wisely ...
# read 2D incidenceAngle, slantRangeDistance from geometry file: geometryGeo.h5
# skip pixels with ZERO / NaN value in incidenceAngle / slantRangeDistance
# number of pixels to invert: 27882 out of 54162 (51.5%)
# estimating DEM error pixel-wisely ...
# skip pixels with ZERO temporal coherence
# skip pixels with ZERO / NaN value in incidenceAngle / slantRangeDistance
# skip pixels with ZERO / NaN value in incidenceAngle / slantRangeDistance
# skip pixels with NaN  in ANY acquisitions
# open geometry file: geometryGeo.h5
# number of pixels to invert: 30441 out of 54162 (56.2%)
# estimating DEM error pixel-wisely ...
# skip pixels with ZERO temporal coherence
# read mean bperp from timeseries file
# skip pixels with ZERO in ALL acquisitions
# number of pixels to invert: 28534 out of 54162 (52.7%)
# estimating DEM error pixel-wisely ...
# read mean bperp from timeseries file
# skip pixels with ZERO in ALL acquisitions
# skip pixels with ZERO / NaN value in incidenceAngle / slantRangeDistance
# number of pixels to invert: 26600 out of 54162 (49.1%)
# estimating DEM error pixel-wisely ...
# skip pixels with NaN  in ANY acquisitions
# skip pixels with ZERO temporal coherence
# skip pixels with NaN  in ANY acquisitions
# skip pixels with ZERO temporal coherence
# skip pixels with ZERO / NaN value in incidenceAngle / slantRangeDistance
# read 2D incidenceAngle, slantRangeDistance from geometry file: geometryGeo.h5
# number of pixels to invert: 26162 out of 54162 (48.3%)
# estimating DEM error pixel-wisely ...
# skip pixels with ZERO / NaN value in incidenceAngle / slantRangeDistance
# number of pixels to invert: 27028 out of 54162 (49.9%)
# estimating DEM error pixel-wisely ...
# read mean bperp from timeseries file
# skip pixels with ZERO / NaN value in incidenceAngle / slantRangeDistance
# skip pixels with ZERO in ALL acquisitions
# number of pixels to invert: 27460 out of 54162 (50.7%)
# estimating DEM error pixel-wisely ...
# read mean bperp from timeseries file
# skip pixels with ZERO in ALL acquisitions
# skip pixels with NaN  in ANY acquisitions
# skip pixels with ZERO temporal coherence
# skip pixels with ZERO / NaN value in incidenceAngle / slantRangeDistance
# number of pixels to invert: 30857 out of 54162 (57.0%)
# estimating DEM error pixel-wisely ...
# skip pixels with ZERO / NaN value in incidenceAngle / slantRangeDistance
# number of pixels to invert: 29169 out of 54162 (53.9%)
# estimating DEM error pixel-wisely ...
# skip pixels with NaN  in ANY acquisitions
# skip pixels with ZERO / NaN value in incidenceAngle / slantRangeDistance
# number of pixels to invert: 25292 out of 54162 (46.7%)
# estimating DEM error pixel-wisely ...
# skip pixels with ZERO temporal coherence
# skip pixels with ZERO / NaN value in incidenceAngle / slantRangeDistance
# number of pixels to invert: 31276 out of 54162 (57.7%)
# estimating DEM error pixel-wisely ...
# skip pixels with ZERO / NaN value in incidenceAngle / slantRangeDistance
# number of pixels to invert: 30013 out of 54162 (55.4%)
# estimating DEM error pixel-wisely ...
# read mean bperp from timeseries file
# skip pixels with ZERO in ALL acquisitions
# skip pixels with ZERO / NaN value in incidenceAngle / slantRangeDistance
# skip pixels with ZERO / NaN value in incidenceAngle / slantRangeDistance
# number of pixels to invert: 29781 out of 54162 (55.0%)
# estimating DEM error pixel-wisely ...
# number of pixels to invert: 25728 out of 54162 (47.5%)
# estimating DEM error pixel-wisely ...
# skip pixels with NaN  in ANY acquisitions
# skip pixels with ZERO temporal coherence
# skip pixels with ZERO / NaN value in incidenceAngle / slantRangeDistance
# number of pixels to invert: 28743 out of 54162 (53.1%)
# estimating DEM error pixel-wisely ...
# skip pixels with ZERO / NaN value in incidenceAngle / slantRangeDistance
# number of pixels to invert: 16485 out of 37111 (44.4%)
# estimating DEM error pixel-wisely ...
# [==================================================] 16485/16485   18s /    12s
# [======================= 67% =====>                ] 18000/27028   19s /     9s
# FUTURE #1 complete. Time used: 25 seconds
# [==================================================] 24863/24863   26s /     7s
# [==================================================] 24427/24427
# [======================= 86% ==============>       ] 26000/30196   26s /     4s
# FUTURE #2 complete. Time used: 32 seconds
# [==================================================] 25728/25728   27s /     5s
# [======================= 82% ============>         ] 24000/29169   26s /     5s
# FUTURE #3 complete. Time used: 32 seconds
# [==================================================] 25292/25292   28s /     6s
#
# FUTURE #4 complete. Time used: 33 seconds
# [==================================================] 26162/26162   27s /     2s
# [======================= 84% =============>        ] 26000/31017   28s /     5s
# FUTURE #5 complete. Time used: 33 seconds
# [======================= 93% =================>    ] 28000/30196   28s /     2s
# FUTURE #6 complete. Time used: 33 seconds
# [==================================================] 27460/27460   28s /     2s
# [======================= 87% ===============>      ] 26000/30013   28s /     4s
# FUTURE #7 complete. Time used: 34 seconds
# [==================================================] 28311/28311   29s /     4s
# [==================================================] 27028/27028   29s /     2s
# [==================================================] 26600/26600   29s /     5s
#
# FUTURE #8 complete. Time used: 35 seconds
# [======================= 98% ====================> ] 28000/28534   29s /     0s
# FUTURE #9 complete. Time used: 35 seconds
# [======================= 90% ================>     ] 28000/31017   29s /     3s
# FUTURE #10 complete. Time used: 35 seconds
# [==================================================] 28743/28743   30s /     1s
#
# [==================================================] 30196/30196
# [==================================================] 27882/27882   30s /     0s
#
# FUTURE #11 complete. Time used: 35 seconds
#
# FUTURE #12 complete. Time used: 35 seconds
# [==================================================] 29781/29781
# [==================================================] 29586/29586
# [======================= 97% ===================>  ] 28000/28952   30s /     0s
# FUTURE #13 complete. Time used: 35 seconds
# [======================= 90% ================>     ] 28000/31276   30s /     3s
# FUTURE #14 complete. Time used: 36 seconds
# [======================= 89% ===============>      ] 28000/31426   31s /     3s
# [==================================================] 30606/30606
#
#
# FUTURE #16 complete. Time used: 36 seconds
# [==================================================] 30000/30441
# FUTURE #17 complete. Time used: 36 seconds
# [==================================================] 29364/29364
# [==================================================] 30857/30857   31s /     3s
#
# FUTURE #18 complete. Time used: 36 seconds
# [==================================================] 30441/30441
#
# FUTURE #19 complete. Time used: 36 seconds
# [======================= 97% ===================>  ] 30000/31017   31s /     0s
# FUTURE #20 complete. Time used: 36 seconds
# [==================================================] 28952/28952
# [==================================================] 29169/29169
#
# FUTURE #21 complete. Time used: 36 seconds
# [======================= 97% ===================>  ] 30000/30800   31s /     0s
# FUTURE #22 complete. Time used: 36 seconds
# [==================================================] 31698/31698
# [======================= 93% =================>    ] 30000/32249   31s /     2s
# FUTURE #23 complete. Time used: 36 seconds
# [==================================================] 30013/30013
# [==================================================] 31017/31017   31s /     0s
# [==================================================] 30800/30800
#
# FUTURE #24 complete. Time used: 36 seconds
#
# FUTURE #25 complete. Time used: 36 seconds
#
# FUTURE #26 complete. Time used: 36 seconds
# [==================================================] 31829/31829
# [======================= 95% ===================>  ] 30000/31426   31s /     1s
# FUTURE #27 complete. Time used: 36 seconds
# [==================================================] 32646/32646
# [======================= 97% ===================>  ] 32000/33053   31s /     0s
# FUTURE #28 complete. Time used: 36 seconds
# [==================================================] 31276/31276
#
# FUTURE #29 complete. Time used: 37 seconds
# [==================================================] 33053/33053
# [==================================================] 31426/31426
#
# FUTURE #30 complete. Time used: 37 seconds
#
# FUTURE #31 complete. Time used: 37 seconds
# [==================================================] 32249/32249
#
# FUTURE #32 complete. Time used: 37 seconds
# close dask client
# 2024-03-12 21:37:57,542 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/home/jovyan/.local/envs/osl_mintpy/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jovyan/.local/envs/osl_mintpy/lib/python3.9/site-packages/distributed/worker.py", line 1237, in heartbeat
#     response = await retry_operation(
#   File "/home/jovyan/.local/envs/osl_mintpy/lib/python3.9/site-packages/distributed/utils_comm.py", line 434, in retry_operation
#     return await retry(
#   File "/home/jovyan/.local/envs/osl_mintpy/lib/python3.9/site-packages/distributed/utils_comm.py", line 413, in retry
#     return await coro()
#   File "/home/jovyan/.local/envs/osl_mintpy/lib/python3.9/site-packages/distributed/core.py", line 1269, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jovyan/.local/envs/osl_mintpy/lib/python3.9/site-packages/distributed/core.py", line 1028, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jovyan/.local/envs/osl_mintpy/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jovyan/.local/envs/osl_mintpy/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:46066 remote=tcp://127.0.0.1:35069>: Stream is closed
# 2024-03-12 21:37:57,545 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/home/jovyan/.local/envs/osl_mintpy/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jovyan/.local/envs/osl_mintpy/lib/python3.9/site-packages/distributed/worker.py", line 1237, in heartbeat
#     response = await retry_operation(
#   File "/home/jovyan/.local/envs/osl_mintpy/lib/python3.9/site-packages/distributed/utils_comm.py", line 434, in retry_operation
#     return await retry(
#   File "/home/jovyan/.local/envs/osl_mintpy/lib/python3.9/site-packages/distributed/utils_comm.py", line 413, in retry
#     return await coro()
#   File "/home/jovyan/.local/envs/osl_mintpy/lib/python3.9/site-packages/distributed/core.py", line 1269, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jovyan/.local/envs/osl_mintpy/lib/python3.9/site-packages/distributed/core.py", line 1028, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jovyan/.local/envs/osl_mintpy/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jovyan/.local/envs/osl_mintpy/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:46178 remote=tcp://127.0.0.1:35069>: Stream is closed
# close dask cluster
# ------- finished parallel processing -------
#
#
# --------------------------------------------------
# open  HDF5 file demErr.h5 in a mode
# writing dataset /dem                       block: [0, 1003, 0, 1711]
# close HDF5 file demErr.h5.
# --------------------------------------------------
# open  HDF5 file /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/timeseries_demErr.h5 in a mode
# writing dataset /timeseries                block: [0, 12, 0, 1003, 0, 1711]
# close HDF5 file /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/timeseries_demErr.h5.
# --------------------------------------------------
# open  HDF5 file /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/timeseriesResidual.h5 in a mode
# writing dataset /timeseries                block: [0, 12, 0, 1003, 0, 1711]
# close HDF5 file /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/timeseriesResidual.h5.
# roll back to the original settings of ['OMP_NUM_THREADS', 'OPENBLAS_NUM_THREADS', 'MKL_NUM_THREADS', 'NUMEXPR_NUM_THREADS', 'VECLIB_MAXIMUM_THREADS']
# remove env variable OMP_NUM_THREADS
# remove env variable OPENBLAS_NUM_THREADS
# remove env variable MKL_NUM_THREADS
# remove env variable NUMEXPR_NUM_THREADS
# remove env variable VECLIB_MAXIMUM_THREADS
# time used: 00 mins 48.7 secs.
# Go back to directory: /home/jovyan/notebooks/SAR_Training/English/Master
#
# ################################################
#    Normal end of smallbaselineApp processing!
# ################################################
# Time used: 00 mins 48.9 secs

# %% [markdown]
# ## 3.9. Calculate the Root Mean Square (RMS) of Residual Phase Time-Series for Each Acquisition
#
# **Run the `residual_RMS` step**
#
# - *reference: Yunjun et al. (2019, section 4.9 and 5.4)*
# - To remove the long wavelength component in space, a phase ramp is removed for each acquisition
# - Sets optimal reference date to date with min RMS
# - Sets exclude dates (outliers) to dates with RMS > cutoff * median RMS (Median Absolute Deviation)

# %%
# !smallbaselineApp.py $config_path --work-dir {mint_path} --dostep residual_RMS
# Out:
# MintPy version 1.5.1, date 2023-01-03
# --RUN-at-2024-03-12 21:39:31.795144--
# Current directory: /home/jovyan/notebooks/SAR_Training/English/Master
# Run routine processing with smallbaselineApp.py on steps: ['residual_RMS']
# Remaining steps: ['reference_date', 'velocity', 'geocode', 'google_earth', 'hdfeos5']
# --------------------------------------------------
# Project name: tuscon
# Go to work directory: /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy
# read custom template file: /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/tuscon.txt
# update default template based on input custom template
# No new option value found, skip updating /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/smallbaselineApp.cfg
# read default template file: /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/smallbaselineApp.cfg
#
#
# ******************** step - residual_RMS ********************
#
# timeseries_rms.py timeseriesResidual.h5 -t /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/smallbaselineApp.cfg
# read options from template file: smallbaselineApp.cfg
# remove quadratic ramp from file: timeseriesResidual.h5
# read mask file: maskTempCoh.h5
# --------------------------------------------------
# grab metadata from ref_file: timeseriesResidual.h5
# grab dataset structure from ref_file: timeseriesResidual.h5
# create HDF5 file: timeseriesResidual_ramp.h5 with w mode
# create dataset  : bperp      of float32                   in size of (12,)                with compression = None
# create dataset  : date       of |S8                       in size of (12,)                with compression = None
# create dataset  : timeseries of float32                   in size of (12, 1003, 1711)     with compression = None
# close  HDF5 file: timeseriesResidual_ramp.h5
# estimating phase ramp one date at a time ...
# [==================================================] 12/12    7s /     0s
# finished writing to file: timeseriesResidual_ramp.h5
# time used: 00 mins 8.6 secs.
#
# calculating residual RMS for each epoch from file: timeseriesResidual_ramp.h5
# read mask from file: maskTempCoh.h5
# reading timeseries data from file: timeseriesResidual_ramp.h5 ...
# [==================================================] 12/12    0s /     0s
# save timeseries RMS to text file: /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/rms_timeseriesResidual_ramp.txt
# read timeseries residual RMS from file: /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/rms_timeseriesResidual_ramp.txt
# --------------------------------------------------
# date with min RMS: 20220522 - 0.0013
# save date to file: reference_date.txt
# --------------------------------------------------
# date(s) with RMS > 3.0 * median RMS (0.0044)
# 20220404 - 0.0051
# save date(s) to file: exclude_date.txt
# save figure to file: /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/rms_timeseriesResidual_ramp.pdf
# Go back to directory: /home/jovyan/notebooks/SAR_Training/English/Master
#
# ################################################
#    Normal end of smallbaselineApp processing!
# ################################################
# Time used: 00 mins 11.2 secs

# %% [markdown]
# ## 3.10. Reference the Entire Time-Series to One Date in Time
#
# **Run the `reference_date` step**
#
# - *reference: Yunjun et al. (2019, section 4.9)*

# %%
# !smallbaselineApp.py $config_path --work-dir {mint_path} --dostep reference_date
# Out:
# MintPy version 1.5.1, date 2023-01-03
# --RUN-at-2024-03-12 21:39:45.149649--
# Current directory: /home/jovyan/notebooks/SAR_Training/English/Master
# Run routine processing with smallbaselineApp.py on steps: ['reference_date']
# Remaining steps: ['velocity', 'geocode', 'google_earth', 'hdfeos5']
# --------------------------------------------------
# Project name: tuscon
# Go to work directory: /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy
# read custom template file: /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/tuscon.txt
# update default template based on input custom template
# No new option value found, skip updating /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/smallbaselineApp.cfg
# read default template file: /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/smallbaselineApp.cfg
#
#
# ******************** step - reference_date ********************
# No reference date change.
# Go back to directory: /home/jovyan/notebooks/SAR_Training/English/Master
#
# ################################################
#    Normal end of smallbaselineApp processing!
# ################################################
# Time used: 00 mins 0.0 secs

# %% [markdown]
# ## 3.11. Estimate The Long-Term Velocity Rate
#
# **Run the `velocity` step**
#
# The timeseries file contains three datasets:
# - the `time-series` dataset, which is the interferometric range change for each acquisition relative to the reference acquisition
# - the `date` dataset, which contains the acquisition date for each acquisition
# - the `bperp` dataset, which contains the timeseries of the perpendicular baseline
#
# The ground deformation caused by many geophysical or anthropogenic processes are linear at first order approximation. Therefore it is common to estimate the rate of the ground deformation which is the slope of linear fit to the time-series.

# %%
# !smallbaselineApp.py $config_path --work-dir {mint_path} --dostep velocity
# Out:
# MintPy version 1.5.1, date 2023-01-03
# --RUN-at-2024-03-12 21:39:51.559609--
# Current directory: /home/jovyan/notebooks/SAR_Training/English/Master
# Run routine processing with smallbaselineApp.py on steps: ['velocity']
# Remaining steps: ['geocode', 'google_earth', 'hdfeos5']
# --------------------------------------------------
# Project name: tuscon
# Go to work directory: /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy
# read custom template file: /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/tuscon.txt
# update default template based on input custom template
# No new option value found, skip updating /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/smallbaselineApp.cfg
# read default template file: /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/smallbaselineApp.cfg
#
#
# ******************** step - velocity ********************
#
# timeseries2velocity.py /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/timeseries_demErr.h5 -t /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/smallbaselineApp.cfg -o /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/velocity.h5 --update
# read options from template file: smallbaselineApp.cfg
# update mode: ON
# 1) output file /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/velocity.h5 already exists.
# 2) output file is NOT newer than input file: /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/timeseries_demErr.h5.
# run or skip: run.
# open timeseries file: timeseries_demErr.h5
# exclude date: ['20220404']
# --------------------------------------------------
# dates from input file: 12
# ['20220110', '20220122', '20220203', '20220215', '20220227', '20220311', '20220323', '20220404', '20220416', '20220428', '20220510', '20220522']
# --------------------------------------------------
# dates used to estimate the time function: 11
# ['20220110', '20220122', '20220203', '20220215', '20220227', '20220311', '20220323', '20220416', '20220428', '20220510', '20220522']
# --------------------------------------------------
# estimate deformation model with the following assumed time functions:
#     polynomial : 1
#     periodic   : []
#     stepDate   : []
#     exp        : {}
#     log        : {}
# add/update the following configuration metadata:
# ['startDate', 'endDate', 'excludeDate', 'polynomial', 'periodic', 'stepDate', 'exp', 'log', 'uncertaintyQuantification', 'timeSeriesCovFile', 'bootstrapCount']
# --------------------------------------------------
# create HDF5 file: /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/velocity.h5 with w mode
# create dataset  : intercept    of <class 'numpy.float32'>   in size of (1003, 1711)         with compression = None
# create dataset  : interceptStd of <class 'numpy.float32'>   in size of (1003, 1711)         with compression = None
# create dataset  : velocity     of <class 'numpy.float32'>   in size of (1003, 1711)         with compression = None
# create dataset  : velocityStd  of <class 'numpy.float32'>   in size of (1003, 1711)         with compression = None
# create dataset  : residue      of <class 'numpy.float32'>   in size of (1003, 1711)         with compression = None
# add /intercept    attribute: UNIT = m
# add /interceptStd attribute: UNIT = m
# add /velocity     attribute: UNIT = m/year
# add /velocityStd  attribute: UNIT = m/year
# add /residue      attribute: UNIT = m
# close  HDF5 file: /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/velocity.h5
# reading data from file /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/timeseries_demErr.h5 ...
# skip pixels with zero/nan value in all acquisitions
# number of pixels to invert: 922475 out of 1716133 (53.8%)
# estimating time functions via linalg.lstsq ...
# estimating time functions STD from time-series fitting residual ...
# --------------------------------------------------
# open  HDF5 file /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/velocity.h5 in a mode
# writing dataset /intercept                 block: [0, 1003, 0, 1711]
# close HDF5 file /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/velocity.h5.
# --------------------------------------------------
# open  HDF5 file /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/velocity.h5 in a mode
# writing dataset /interceptStd              block: [0, 1003, 0, 1711]
# close HDF5 file /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/velocity.h5.
# --------------------------------------------------
# open  HDF5 file /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/velocity.h5 in a mode
# writing dataset /velocity                  block: [0, 1003, 0, 1711]
# close HDF5 file /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/velocity.h5.
# --------------------------------------------------
# open  HDF5 file /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/velocity.h5 in a mode
# writing dataset /velocityStd               block: [0, 1003, 0, 1711]
# close HDF5 file /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/velocity.h5.
# --------------------------------------------------
# open  HDF5 file /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/velocity.h5 in a mode
# writing dataset /residue                   block: [0, 1003, 0, 1711]
# close HDF5 file /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/velocity.h5.
# time used: 00 mins 0.8 secs.
# Go back to directory: /home/jovyan/notebooks/SAR_Training/English/Master
#
# ################################################
#    Normal end of smallbaselineApp processing!
# ################################################
# Time used: 00 mins 0.9 secs

# %% [markdown]
# **Plot the velocity map**
#
# Note: The min/max values in this plot should be adjusted to your data set.
#
# The output of the following call will show a data range. You can run the cell once to collect this information and re-run it after adjustments are made.
#
# - You should update `vmin` and `vmax` to match your data range
# - The `vmin` and `vmax` values that you assign will be used for additional plots in this notebook
# - If you wish to set 0 deformation to the center of the color scale (green), adjust your min/max values so they are symmetrical
#     - For example, given a data range of `[-10.691118, 13.904866]`, appropriate symmetrical min/max values would be `[-14.0, 14.0]`

# %%
# %matplotlib inline
vmin = -3
vmax = 3

scp_args = f'{mint_path}/velocity.h5 velocity -v {vmin} {vmax} --dpi 600 --figsize 15 15 --outfile {plot_path}/velocity.png --update'
view.main(scp_args.split())
# Out:
# run view.py in MintPy version 1.5.1, date 2023-01-03
# input file is velocity file: /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/velocity.h5 in float32 format
# file size in y/x: (1003, 1711)
# input dataset: "['velocity']"
# turning glob search OFF for velocity file
# num of datasets in file velocity.h5: 5
# datasets to exclude (0):
# []
# datasets to display (1):
# ['velocity']
# inps: Namespace(file='/home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/velocity.h5', dset=['velocity'], dsetNumList=[0], search_dset=False, exDsetList=[], plot_drop_ifgram=True, print_msg=True, math_operation=None, vlim=[-3.0, 3.0], disp_unit=None, no_data_value=None, wrap=False, wrap_range=[-3.141592653589793, 3.141592653589793], flip_lr=False, flip_ud=False, auto_flip=True, multilook_num=1, multilook=True, transparency=None, dem_file=None, mask_dem=False, disp_dem_shade=True, disp_dem_contour=True, dem_contour_smooth=3.0, dem_contour_step=200.0, dem_contour_linewidth=0.5, shade_azdeg=315.0, shade_altdeg=45.0, shade_min=-4000.0, shade_max=999.0, shade_exag=0.5, font_size=None, font_color='k', disp_whitespace=True, disp_axis=True, disp_tick=True, ylabel_rot=None, colormap=None, cmap_lut=256, cmap_vlist=[0.0, 0.7, 1.0], disp_cbar=True, cbar_nbins=None, cbar_ext=None, cbar_label=None, cbar_loc='right', cbar_size='2%', disp_title=True, fig_title_in=False, fig_title=None, disp_title4sentinel1=False, fig_size=[15.0, 15.0], fig_dpi=600, fig_ext='.png', fig_num=None, fig_row_num=1, fig_col_num=1, fig_wid_space=None, fig_hei_space=None, fig_tight_layout=True, fig_coord='geo', animation=False, disp_gps=False, mask_gps=False, disp_gps_label=False, gps_marker_size=6, gps_component=None, gps_redo=False, ref_gps_site=None, ex_gps_sites=None, gps_start_date=None, gps_end_date=None, horz_az_angle=-90.0, mask_file=None, mask_vmin=None, mask_vmax=None, zero_mask=False, coastline=None, coastline_linewidth=1, lalo_label=False, lalo_step=None, lalo_max_num=3, lalo_loc=[1, 0, 0, 1], lalo_offset=None, lalo_font_size=None, scalebar=[0.2, 0.2, 0.1], disp_scalebar=True, scalebar_pad=0.05, maxMemory=4.0, pts_marker='k^', pts_marker_size=6.0, pts_yx=None, pts_lalo=None, pts_file=None, ref_date=None, ref_lalo=None, ref_yx=None, disp_ref_pixel=True, ref_marker='ks', ref_marker_size=6, outfile=['/home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/plots/velocity.png'], save_fig=True, disp_fig=True, update_mode=True, subset_x=None, subset_y=None, subset_lat=None, subset_lon=None, argv=['/home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/velocity.h5', 'velocity', '-v', '-3', '3', '--dpi', '600', '--figsize', '15', '15', '--outfile', '/home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/plots/velocity.png', '--update'], length=1003, width=1711, key='velocity', fileBase='velocity', fileExt='.h5', sliceList=['velocity', 'velocityStd', 'intercept', 'interceptStd', 'residue'], exDsetNumList=[], dsetNum=1)
# slef.atr: {'ALOOKS': '4', 'ANTENNA_SIDE': '-1', 'AZIMUTH_PIXEL_SIZE': '56.4', 'BANDS': '1', 'CENTER_LINE_UTC': '48477.595274', 'DATA_TYPE': 'float32', 'DATE12': '20220110_20220522', 'EARTH_RADIUS': '6371592.8384', 'END_DATE': '20220522', 'EPSG': '4326', 'FILE_LENGTH': '1003', 'FILE_PATH': '/home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/velocity.h5', 'FILE_TYPE': 'velocity', 'HEADING': '-167.0228635', 'HEIGHT': '699905.2618000004', 'INTERLEAVE': 'BSQ', 'LAT_REF1': '34.74299654878383', 'LAT_REF2': '34.74299654878383', 'LAT_REF3': '33.935000101884505', 'LAT_REF4': '33.935000101884505', 'LENGTH': '1003', 'LON_REF1': '-111.20667753051981', 'LON_REF2': '-112.58502441052454', 'LON_REF3': '-111.20667753051981', 'LON_REF4': '-112.58502441052454', 'NO_DATA_VALUE': '0.0', 'NoDataValue': '0.0', 'OG_FILE_PATH': '/home/jovyan/notebooks/SAR_Training/English/Master/tuscon/S1AA_20220110T132756_20220122T132756_VVP012_INT80_G_ueF_DB6D/S1AA_20220110T132756_20220122T132756_VVP012_INT80_G_ueF_DB6D_unw_phase_clip_clip.tif', 'ORBIT_DIRECTION': 'DESCENDING', 'PLATFORM': 'Sen', 'PROCESSOR': 'hyp3', 'PROJECT_NAME': 'tuscon', 'P_BASELINE_BOTTOM_HDR': '22.1241', 'P_BASELINE_TOP_HDR': '22.1241', 'RANGE_PIXEL_SIZE': '46.0', 'REF_DATE': '20220110', 'REF_LAT': '34.31966441234754', 'REF_LON': '-111.74117966662918', 'REF_X': '1047', 'REF_Y': '525', 'RLOOKS': '20', 'STARTING_RANGE': '799241.8798', 'START_DATE': '20220110', 'UNIT': 'm/year', 'WAVELENGTH': '0.055465764662349676', 'WIDTH': '1711', 'X_FIRST': '-112.58502441052454', 'X_STEP': '0.0008055797077759953', 'X_UNIT': 'degrees', 'Y_FIRST': '34.74299654878383', 'Y_STEP': '-0.0008055797077759953', 'Y_UNIT': 'degrees', 'mintpy.compute.cluster': 'local', 'mintpy.compute.numWorker': '32', 'mintpy.load.azAngleFile': '/home/jovyan/notebooks/SAR_Training/English/Master/tuscon/*/*lv_phi*.tif', 'mintpy.load.corFile': '/home/jovyan/notebooks/SAR_Training/English/Master/tuscon/*/*corr*.tif', 'mintpy.load.demFile': '/home/jovyan/notebooks/SAR_Training/English/Master/tuscon/*/*dem*.tif', 'mintpy.load.incAngleFile': '/home/jovyan/notebooks/SAR_Training/English/Master/tuscon/*/*lv_theta*.tif', 'mintpy.load.processor': 'hyp3', 'mintpy.load.unwFile': '/home/jovyan/notebooks/SAR_Training/English/Master/tuscon/*/*unw_phase*.tif', 'mintpy.load.waterMaskFile': '/home/jovyan/notebooks/SAR_Training/English/Master/tuscon/*/*water_mask*.tif', 'mintpy.networkInversion.maskDataset': 'False', 'mintpy.networkInversion.maskThreshold': '0.4', 'mintpy.networkInversion.minNormVelocity': 'True', 'mintpy.networkInversion.minRedundancy': '1.0', 'mintpy.networkInversion.numIfgram': '38', 'mintpy.networkInversion.obsDatasetName': 'unwrapPhase', 'mintpy.networkInversion.weightFunc': 'var', 'mintpy.reference.date': 'no', 'mintpy.reference.lalo': '34.04859,-111.3806', 'mintpy.timeFunc.bootstrapCount': '400', 'mintpy.timeFunc.endDate': 'None', 'mintpy.timeFunc.excludeDate': "['exclude_date.txt']", 'mintpy.timeFunc.exp': '[]', 'mintpy.timeFunc.log': '[]', 'mintpy.timeFunc.periodic': '[]', 'mintpy.timeFunc.polynomial': '1', 'mintpy.timeFunc.startDate': 'None', 'mintpy.timeFunc.stepDate': '[]', 'mintpy.timeFunc.timeSeriesCovFile': 'None', 'mintpy.timeFunc.uncertaintyQuantification': 'residue', 'mintpy.topographicResidual.excludeDate': "['20220323', '20220404']", 'mintpy.topographicResidual.phaseVelocity': 'False', 'mintpy.topographicResidual.polyOrder': '2', 'mintpy.topographicResidual.stepFuncDate': '[]', 'mintpy.troposphericDelay.method': 'no'}
# data   coverage in y/x: (0, 0, 1711, 1003)
# subset coverage in y/x: (0, 0, 1711, 1003)
# data   coverage in lat/lon: (-112.58502441052454, 34.74299654878383, -111.20667753051981, 33.935000101884505)
# subset coverage in lat/lon: (-112.58502441052454, 34.74299654878383, -111.20667753051981, 33.935000101884505)
# ------------------------------------------------------------------------
# colormap: jet
# figure title: velocity
# inps: Namespace(file='/home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/velocity.h5', dset=['velocity'], dsetNumList=[0], search_dset=False, exDsetList=[], plot_drop_ifgram=True, print_msg=True, math_operation=None, vlim=[-3.0, 3.0], disp_unit='cm', no_data_value=None, wrap=False, wrap_range=[-3.141592653589793, 3.141592653589793], flip_lr=False, flip_ud=False, auto_flip=True, multilook_num=1, multilook=True, transparency=1.0, dem_file=None, mask_dem=False, disp_dem_shade=True, disp_dem_contour=True, dem_contour_smooth=3.0, dem_contour_step=200.0, dem_contour_linewidth=0.5, shade_azdeg=315.0, shade_altdeg=45.0, shade_min=-4000.0, shade_max=999.0, shade_exag=0.5, font_size=16, font_color='k', disp_whitespace=True, disp_axis=True, disp_tick=True, ylabel_rot=None, colormap='jet', cmap_lut=256, cmap_vlist=[0.0, 0.7, 1.0], disp_cbar=True, cbar_nbins=None, cbar_ext=None, cbar_label=None, cbar_loc='right', cbar_size='2%', disp_title=True, fig_title_in=False, fig_title='velocity', disp_title4sentinel1=False, fig_size=[15.0, 15.0], fig_dpi=600, fig_ext='.png', fig_num=None, fig_row_num=1, fig_col_num=1, fig_wid_space=None, fig_hei_space=None, fig_tight_layout=True, fig_coord='geo', animation=False, disp_gps=False, mask_gps=False, disp_gps_label=False, gps_marker_size=6, gps_component=None, gps_redo=False, ref_gps_site=None, ex_gps_sites=None, gps_start_date=None, gps_end_date=None, horz_az_angle=-90.0, mask_file=None, mask_vmin=None, mask_vmax=None, zero_mask=False, coastline=None, coastline_linewidth=1, lalo_label=False, lalo_step=None, lalo_max_num=3, lalo_loc=[1, 0, 0, 1], lalo_offset=None, lalo_font_size=None, scalebar=[0.2, 0.2, 0.1], disp_scalebar=True, scalebar_pad=0.05, maxMemory=4.0, pts_marker='k^', pts_marker_size=6.0, pts_yx=None, pts_lalo=None, pts_file=None, ref_date=None, ref_lalo=[34.31966441234754, -111.74117966662918], ref_yx=None, disp_ref_pixel=True, ref_marker='ks', ref_marker_size=6, outfile=['/home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/plots/velocity.png'], save_fig=True, disp_fig=True, update_mode=True, subset_x=None, subset_y=None, subset_lat=None, subset_lon=None, argv=['/home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/velocity.h5', 'velocity', '-v', '-3', '3', '--dpi', '600', '--figsize', '15', '15', '--outfile', '/home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/plots/velocity.png', '--update'], length=1003, width=1711, key='velocity', fileBase='velocity', fileExt='.h5', sliceList=['velocity', 'velocityStd', 'intercept', 'interceptStd', 'residue'], exDsetNumList=[], dsetNum=1, pix_box=(0, 0, 1711, 1003), geo_box=(-112.58502441052454, 34.74299654878383, -111.20667753051981, 33.935000101884505), data_box=(0, 0, 1711, 1003), map_proj_obj=None, coord_unit='degrees')
# update mode: ON
# read mask from file: maskTempCoh.h5
# reading data ...
# masking data
# masking pixels with NO_DATA_VALUE of 0.0
# data    range: [-5.5290995, 4.239636] cm/year
# display range: [-3.0, 3.0] cm/year
# display data in transparency: 1.0
# plot in geo-coordinate
# plotting image ...
# plot scale bar: [0.2, 0.2, 0.1]
# plot reference point
# save figure to /home/jovyan/notebooks/SAR_Training/English/Master/tuscon_h5_only/MintPy/plots/velocity.png with dpi=600
# showing ...

# %% [markdown]
# <div class="alert alert-info">
# <b>Note :</b>
# Negative values indicates that target is moving away from the radar (i.e., Subsidence in case of vertical deformation).
# Positive values indicates that target is moving towards the radar (i.e., uplift in case of vertical deformation).
# </div>

# %% [markdown]
# ## 3.12. Geocode velocity.h5 in Preparation for Creating a velocity.kmz
#
# **Run the `geocode` step**
#
# - This is unnecessary for geocoded HyP3 data but would be needed for non-geocoded data

# %%
# !smallbaselineApp.py $config_path --work-dir {mint_path} --dostep geocode
# Out:
# MintPy version 1.5.1, date 2023-01-03
# --RUN-at-2024-03-12 21:40:15.875719--
# Current directory: /home/jovyan/notebooks/SAR_Training/English/Master
# Run routine processing with smallbaselineApp.py on steps: ['geocode']
# Remaining steps: ['google_earth', 'hdfeos5']
# --------------------------------------------------

# %% [markdown]
# ## 3.13. Create a kmz File
#
# **Run the `google_earth` step**

# %%
# !smallbaselineApp.py $config_path --work-dir {mint_path} --dostep google_earth

# %% [markdown]
# ## 3.14 Plot the unwrapped inverted timeseries
#
# **Create directories in which to store output we will create in upcoming steps**

# %%
geotiff_path = mint_path/'GeoTiffs'
geotiff_path.mkdir(exist_ok=True)

disp_path = geotiff_path/'displacement_maps'
disp_path.mkdir(exist_ok=True)

wrapped_path = disp_path/"wrapped"
wrapped_path.mkdir(exist_ok=True)

unwrapped_path = disp_path/"unwrapped"
unwrapped_path.mkdir(exist_ok=True)

demErr = 'timeseries_ERA5_demErr.h5' if correct_tropo else 'timeseries_demErr.h5'
ts_demErr = mint_path/f'{demErr}'

# %% [markdown]
# **Plot the unwrapped inverted time series steps (n, n+1, n+2, etc...)**
#
# - save a png

# %%
scp_args = f'{ts_demErr} --notitle --notick --noaxis -v {vmin} {vmax} --dpi 600 --figsize 15 15 --outfile {unwrapped_path}/unwrapped_inverted_ts.png'
view.main(scp_args.split())

# %% [markdown]
# # 4. Error analysis (signal vs noise)
#
# Uncertainty of the ground displacement products derived from InSAR time-series, depends on the quality of the inversion of the stack of interferograms and the accuracy in separating the ground displacement from other components of the InSAR data. Therefore the definition of signal vs noise is different at the two main steps in MintPy:
#
# 1) During the inversion:
#     At this step all systematic components of the interferometric phase (e.g., ground displacement, propagation delay, geometrical residuals caused by DEM or platform's orbit inaccuracy) are considered signal, while the interferometric phase decorrelation, phase unwrapping error and phase inconsistency are considered noise.
#
# 2) After inversion: the ground displacement component of the time-serieses is signal, and everything else (including the propagation delay and geometrical residuals) are considered noise
#
# Therefore we first discuss the possible sources of error during the inversion and the existing ways in MintPy to evaluate the quality of inversion and to improve the uncertainty of the inversion. Afterwards we explain the different components of the time-series and the different processing steps in MintPy to separate them from ground displacement signal.

# %% [markdown]
# ## 4.1. Quality of the inversion
#
# The main sources of noise during the time-series inversion includes decorrelation, phase unwrapping error and the inconsistency of triplets of interferofgrams. Here we mainly focus on the decorrelation and unwrapping errors. We first show the existing quantities in MintPy to evaluate decorrelation and unwrapping errors and then discuss the existing ways in MintPy to reduce the decorrelation and unwrapping errors on the time-series inversion.
#
# ### 4.1.1. Average spatial coherence
#
# Mintpy computes temporal average of spatial coherence of the entire stack as a potential ancillary measure to choose reliable pixels after time-series inversion.

# %%
# %matplotlib inline
scp_args = f"{mint_path}/avgSpatialCoh.h5 --dpi 600 --figsize 15 15 --outfile {plot_path}/avg_spatial_coh.png"
view.main(scp_args.split())

# %% [markdown]
# ### 4.1.2. Temporal coherence
#
# In addition to timeseries.h5 which contains the time-series dataset, invert_network produces other quantities, which contain metrics to evaluate the quality of the inversion including temporalCoherence.h5. Temporal coherence represents the consistency of the timeseries with the network of interferograms.
#
# Temporal coherence varies from 0 to 1. Pixels with values closer to 1 are considered reliable and pixels with values closer to zero are considered unreliable. For a dense network of interferograms, a threshold of 0.7 may be used (Yunjun et al, 2019).

# %%
# %matplotlib inline
scp_args = f"{mint_path}/temporalCoherence.h5 --dpi 600 --figsize 15 15 --outfile {plot_path}/temporal_coh.png"
view.main(scp_args.split())

# %% [markdown]
# ## 4.2. Velocity error analysis
#
# The estimated velocity also comes with an expression of unecrtainty which is simply based on the goodness of fit while fitting a linear model to the time-series. This quantity is saved in "velocity.h5" under the velocityStd dataset.

# %%
# %matplotlib inline
scp_args = f'{mint_path}/velocity.h5 velocityStd -v 0 1 --dpi 600 --figsize 15 15 --outfile {plot_path}/velocity_err.png'
view.main(scp_args.split())

# %% [markdown]
# Note that the plot above is the velocity error, not the velocity. The errors generally increases with distance from the reference point and can also increase for points with elevations different from the reference point if topographically correlated water vapor variations are especially strong in the area.

# %% [markdown]
# ## 4.3. Compare InSAR time-series with GPS time-series in LOS direction
# ---
# > ## Due to the following issue, the GPS section of this notebook is temporarily broken and the code has been commented out:
# > https://github.com/insarlab/MintPy/issues/1145
#
# ---
#
# - http://geodesy.unr.edu/NGLStationPages/gpsnetmap/GPSNetMap.html
# - http://geodesy.unr.edu/NGLStationPages/DataHoldings.txt
#
# ### 4.3.1. Identify Potential GPS stations
#
# **Write the University of Nevada, Reno GPS station holdings metadata to GPS_stations.csv**

# %%
with asfn.work_dir(mint_path):
    url = 'http://geodesy.unr.edu/NGLStationPages/DataHoldings.txt'
    response = urllib.request.urlopen(url, timeout=5)
    content = response.read()
    rows = content.decode('utf-8').splitlines()
    holdings_txt = Path('.')/'DataHoldings.txt'
    if holdings_txt.exists():
        holdings_txt.unlink()

with open(f'{mint_path}/GPS_stations.csv', 'w', newline='') as csvfile:
    csv_writer = csv.writer(csvfile, delimiter=',', escapechar=',', quoting=csv.QUOTE_NONE)
    for row in rows:
        csv_writer.writerow([re.sub('\s+', ' ', row)])

# %% [markdown]
# **Build a list of GPS stations within your area of interest**

# %%
def convert_long(long):
    if long > 180:
        long = long - 360
    return long

# get the InSAR stack's corner coordinates
with h5py.File(f"{mint_path}/inputs/geometryGeo.h5", 'r') as f:
    lon_west = float(f.attrs['LON_REF1'])
    lon_east = float(f.attrs['LON_REF2'])
    lat_south = float(f.attrs['LAT_REF1'])
    lat_north = float(f.attrs['LAT_REF3'])

# get the start and end dates of the timeseries
if correct_tropo:
    info = gdal.Info(f"{mint_path}/timeseries_ERA5_demErr.h5", format='json')
else:
    info = gdal.Info(f"{mint_path}/timeseries_demErr.h5", format='json')
ts_start = info['metadata']['']['START_DATE']
ts_start = datetime.strptime(ts_start, '%Y%m%d')
ts_end = info['metadata']['']['END_DATE']
ts_end = datetime.strptime(ts_end, '%Y%m%d')

# find all stations that have data within the ts time range,
# are located within the AOI and at an unmasked pixel location
gps_stations = list()
with open(f'{mint_path}/GPS_stations.csv', newline='') as csvfile:
    csv_reader = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in list(csv_reader)[1:]:
        begin_date = datetime.strptime(row[7], '%Y-%m-%d')
        mod_date = datetime.strptime(row[9], '%Y-%m-%d')
        lat = float(row[1])
        
        lon = convert_long(float(row[2]))

        n = [lat, lon]
        a = [lat_north, lon_west]
        b = [lat_south, lon_west]
        c = [lat_south, lon_east]
        ab = np.subtract(a, b)
        an = np.subtract(a, n)
        bc = np.subtract(b, c)
        bn = np.subtract(b, n)

        in_aoi = 0 <= np.dot(ab, an) <= np.dot(ab, ab) and 0 <= np.dot(bc, bn) <= np.dot(bc, bc)
        in_date_range = ts_start >= begin_date and ts_end <= mod_date
        
        if in_aoi and in_date_range:
            vel_file = f'{mint_path}/velocity.h5'
            atr = mintpy.utils.readfile.read_attribute(vel_file)
            coord = mintpy.utils.utils.coordinate(atr, lookup_file=f'{mint_path}/inputs/geometryRadar.h5')
            x = coord.lalo2yx(lon, 'lon')
            y = coord.lalo2yx(lat, 'lat')

            vel, _ = mintpy.utils.readfile.read(f"{mint_path}/velocity.h5", datasetName='velocity')
            yx_vel = (vel[y][x])

            # remove gps stations in no-data areas of raster
            if yx_vel != 0.0:
                gps_stations.append(row[0].strip())

# There must be at least 2 GPS stations in your AOI
gps = len(gps_stations) > 1
if not gps:
    print("There were fewer than 2 GPS sites found in your AOI")

# %% [markdown]
# **Create a dictionary of metadata for each GPS site in yoour AOI**

# %%
if gps:
    def get_gps_dict(stations):
        gps_dict = {}
        with open(f'{mint_path}/GPS_stations.csv', newline='') as csvfile:
            csv_reader = csv.reader(csvfile, delimiter=' ', quotechar='|')
            for row in list(csv_reader)[1:]:
                if row[0] in stations:
                    gps_dict[row[0]] = {
                        'lat': row[1],
                        'long': row[2],
                        'height':row[3],
                        'x': row[4],
                        'y': row[5],
                        'z': row[6],
                        'date_beg': row[7],
                        'date_end': row[8],
                        'date_mod': row[9],
                        'num_sol': row[10],
                        'st_og_name': 'na'
                    }
                    if len(row) > 11:
                         gps_dict[row[0]]['st_og_name'] = row[11]
        return gps_dict
    
    gps_dict = get_gps_dict(gps_stations)

    _, my_dict = mintpy.utils.readfile.read(f'{mint_path}/inputs/geometryGeo.h5', datasetName='height')

    x_first = float(my_dict['X_FIRST'])
    x_step = float(my_dict['X_STEP'])
    width = float(my_dict['WIDTH'])

    y_first = float(my_dict['Y_FIRST'])
    y_step = float(my_dict['Y_STEP'])
    height = float(my_dict['LENGTH'])

    # (xmin, ymin, xmax, ymax)
    bounds = (x_first, y_first+(y_step*height), x_first+(x_step*width),  y_first)
    epsg = int(my_dict['EPSG'])

    # convert bounds to web-mercator (epsg:3857)
    xmin, ymin, xmax, ymax = transform_bounds(epsg, 3857, *bounds)

# %% [markdown]
# **Plot the GPS station locations in your AOI**
#
# Hover over GPS sites to view site metadata

# %%
if gps:
    output_notebook()

    longs = [convert_long(float(gps_dict[k]['long'])) for k in gps_stations]
    lats = [float(gps_dict[k]['lat']) for k in gps_stations]
    xy_web = transform(4326, 3857, longs, lats)

    source = DataFrame(
        data=dict(
            x=xy_web[0],
            y=xy_web[1],
            stations=gps_dict.keys(),
            lats=[gps_dict[k]['lat'] for k in gps_dict],
            longs=[convert_long(float(gps_dict[k]['long'])) for k in gps_dict],
            exes=[gps_dict[k]['x'] for k in gps_dict],
            whys=[gps_dict[k]['y'] for k in gps_dict],
            zees=[gps_dict[k]['z'] for k in gps_dict],
            heights=[gps_dict[k]['height'] for k in gps_dict],
            start_dates=[gps_dict[k]['date_beg'] for k in gps_dict],
            end_dates=[gps_dict[k]['date_end'] for k in gps_dict],
            mod_dates=[gps_dict[k]['date_mod'] for k in gps_dict],
            num_sols=[gps_dict[k]['num_sol'] for k in gps_dict],
            og_names=[gps_dict[k]['st_og_name'] for k in gps_dict],
        )
    )

    labels = LabelSet(
                x='x',
                y='y',
                text='stations',
                level='glyph',
                x_offset=-15, 
                y_offset=15, 
                source=ColumnDataSource(source))

    TOOLTIPS = [
        ("station", "@stations"),
        ("lat(deg)", "@lats"),
        ("long(deg)", '@longs'),
        ('height(m)', '@heights'), 
        ("x(m)", '@exes'),
        ("y(m)", "@whys"),
        ("z(m)", "@zees"),
        ("start date", "@start_dates"),
        ("end date", "@end_dates"),
        ("modification date", "@mod_dates"),
        ("NumSol", "@num_sols"),
        ("original station name", "@og_names")

    ]

    # range bounds supplied in web mercator coordinates
    p = figure(x_range=(xmin, xmax), y_range=(ymin, ymax),
               x_axis_type="mercator", y_axis_type="mercator", tooltips=TOOLTIPS)

    p.add_tile('CARTODBPOSITRON')
    p.circle_dot(x='x', y='y', size=20, fill_alpha=0.2, color='red', alpha=0.6, source=source)

    p.add_layout(labels)
    
    p.title = "GPS Site Locations"

    velocity_png_pth = plot_path/"velocity.png"
    with open(velocity_png_pth, 'rb') as f:
        encoded_image = base64.b64encode(f.read()).decode('utf-8')

    
    data_url = f'data:image/png;base64,{encoded_image}'
    div = Div(text=f'<img src="{data_url}" alt="velocity png" width="600px"/>')
    layout = bokeh.layouts.row(p, div)

    show(layout)

# %% [markdown]
# **Select a GPS station**

# %%
if gps:
    gps_station = widgets.RadioButtons(
        options=gps_stations,
        description='',
        disabled=False,
        layout=Layout(min_width='800px'))
    
    print("Select a GPS station")
    display(gps_station)

# %% [markdown]
# **Plot the GPS/velocity comparison**

# %%
# %matplotlib widget
if gps:
    scp_args = f"{mint_path}/velocity.h5 velocity -v {vmin} {vmax} --show-gps --ref-gps {gps_station.value} --gps-comp enu2los --gps-label --figsize 9 9"
    with asfn.work_dir(mint_path):
        view.main(scp_args.split())

# %% [markdown]
# # 5. Plotting a Motion Transect
#
# **Select the transect to plot**

# %%
# %matplotlib widget
data, _ = mintpy.utils.readfile.read(f"{mint_path}/velocity.h5", datasetName='velocity')

# Add vmix and vmax buffers to match scaling of transect plot generated by MintPy
velocity_vmin = np.round(np.nanmin(data), 2)
velocity_vmax = np.round(np.nanmax(data), 2)
v = np.max([np.abs(velocity_vmin), np.abs(velocity_vmax)])
v = sorted([v, np.round(v*-1, 2)])

mask = np.ma.masked_where(data==0, data)
data = mask.filled(fill_value=np.nan)
line = asfn.LineSelector(data, figsize=(9, 9), cmap='jet', vmin=v[0], vmax=v[1])

# %%
amp = list(work_path.glob('*/*_amp_clip.tif'))[0]
amp = gdal.Open(str(amp))
geotrans = amp.GetGeoTransform()

def geolocation(x, y, geotrans):
    return [geotrans[0]+x*geotrans[1], geotrans[3]+y*geotrans[5]]

try:
    pnt_1 = geolocation(line.pnt1[0][0], line.pnt1[0][1], geotrans)
    pnt_2 = geolocation(line.pnt2[0][0], line.pnt2[0][1], geotrans)
    print(f"point 1: {pnt_1}")
    print(f"point 2: {pnt_2}")
except TypeError:
    print('TypeError')
    display(Markdown(f'<text style=color:red>This error may occur if a line was not selected.</text>'))

# %%
scp_args = f'{mint_path}/velocity.h5 -v {vmin} {vmax} --start-lalo {pnt_1[1]} {pnt_1[0]} --end-lalo {pnt_2[1]} {pnt_2[0]} --outfile x'

with asfn.work_dir(plot_path):
    # let MintPy cleanup its old subplots 
    # this has been fixed in MintPy 1.5.3 but is required for 1.5.1
    plot_transection.main(scp_args.split()[:-2] + ['--noverbose', '--nodisplay'])
    # plot transection after removing old subplots
    # %matplotlib inline
    plot_transection.main(scp_args.split())

# %% [markdown]
# # 6. Plot the Cumulative Displacement Map and Point Displacement Time Series
#
# - Use the `Time` bar below the Cumulative Displacement Map to view displacements for different time periods
# - Click on the Cumulative Displacement Map to select points for displaying Point Displacement Time-Series

# %%
# %matplotlib widget

tsview.main([str(ts_demErr), 
                    f'-d={mint_path}/inputs/geometryGeo.h5', 
                    f'-o={mint_path}/displacement_ts', 
                    f'--outfile={mint_path}/displacement_ts.pdf'])

# %% [markdown]
# # 7. Generate coherence, velocity, and total displacement Geotiffs
#
# **Create a list dates for all timesteps**

# %%
ifgramstack = inputs_path/"ifgramStack.h5"

with h5py.File(ifgramstack, "r") as f:
    dates = f["date"][()]
    dates = list(set([d.decode("utf-8") for insar in dates for d in insar]))
    dates.sort()
dates

# %% [markdown]
# **Save the full displacement timeseries**

# %%
ds = f'{dates[0]}_{dates[-1]}'
# !save_gdal.py $ts_demErr -d $ds --of GTIFF -o $geotiff_path/"save_gdal_ts_demErr.tif"

# %% [markdown]
# **Save the unwrapped displacement GeoTiffs**

# %%
with h5py.File(ifgramstack, 'r') as f:
    unw_pth = f.attrs['FILE_PATH']

ds_unw = rasterio.open(unw_pth, 'r', driver='GTiff')

for i, d in enumerate(tqdm(dates)):
    date_range = f'{dates[0]}_{dates[i]}'
    cmd = f'view.py {ts_demErr} {date_range} --notitle --notick --noaxis'
    data, _, _ = mintpy.view.prep_slice(cmd)
    data = data / 100 # cm -> meters
        

    with rasterio.open(f'{unwrapped_path}/{date_range}_{ts_demErr.stem}_unwrapped.tif', 'w', driver='GTiff',
                  height = data.shape[0], width = data.shape[1],
                  count=1, dtype=str(data.dtype),
                  crs=ds_unw.read_crs(),
                  transform=ds_unw.transform,
                  nodata=np.nan) as ds:
        
        ds.write(data.astype(rasterio.float32), 1)

# %% [markdown]
# **Write a function to add a color ramp to single band GeoTiff**

# %%
def colorize_wrapped_insar(tif_path: Union[str, Path]):
    """
    Blue: 0 and 2π
    Red: π/2
    Yellow: π
    Green 3/2π
    """
    ds = gdal.Open(str(tif_path), 1)
    band = ds.GetRasterBand(1)

    # create color table
    colors = gdal.ColorTable()
    
    colors.CreateColorRamp(0, (0, 0, 255),  64, (255, 0, 0)) 
    colors.CreateColorRamp(64, (255, 0, 0),   128, (255, 255, 0))
    colors.CreateColorRamp(128, (255, 255, 0), 192, (0, 255, 0))
    colors.CreateColorRamp(192, (0, 255, 0),   255, (0, 0, 255))

    # set color table and color interpretation
    band.SetRasterColorTable(colors)
    band.SetRasterColorInterpretation(gdal.GCI_PaletteIndex)

    # close and save file
    del band, ds

# %% [markdown]
# **Collect paths to unwrapped displacement maps**

# %%
unwrapped_paths = list(unwrapped_path.rglob('*_unwrapped.tif'))
unwrapped_paths

# %% [markdown]
# **Generate the wrapped interferogram GeoTiffs**
#
# - Please note that the wrapped range used below is currently under review and may not yet correctly correspond to the Sentinel-1 wavelength

# %%
sentinel_c_band_lambda = 5.5465763

for unw_path in tqdm(unwrapped_paths):
    date_range_regex = '(?<=/unwrapped/)\d{8}_\d{8}'
    date_range = re.search(date_range_regex, str(unw_path)).group(0)
    
    with rxr.open_rasterio(unw_path, masked=True).squeeze() as ds:
        # convert unwrapped raster to radians
        with xr.set_options(keep_attrs=True):
            unw_rad = (ds * -4 * np.pi) / sentinel_c_band_lambda
          
    # I don't know what it means to convert meters to radians
    # since we did that to the unw data, let's try doing the same to the wrapped range
    wrap_range = [
        (-2.8 * -4 * np.pi) / (sentinel_c_band_lambda * 100),
        (2.8 * -4 * np.pi) / (sentinel_c_band_lambda * 100)
    ]
       
    # wrap the interferogram
    with xr.set_options(keep_attrs=True):
        wrap = mintpy.utils.utils0.wrap(unw_rad, wrap_range=wrap_range)
        
    # collect crs and transform
    with rasterio.open(unw_path, 'r', driver='GTiff') as ds:
        unw_crs = ds.read_crs()
        unw_transform = ds.transform
    
    # Save wrapped interferogram as a GeoTiff
    wrp_path = wrapped_path/f'{date_range}_{ts_demErr.stem}_wrapped_unscaled.tif'
    with rasterio.open(wrp_path, 'w', driver='GTiff',
                      height = wrap.shape[0], width = wrap.shape[1],
                      count=1, dtype=str(wrap.dtype),
                      crs=unw_crs,
                      transform=unw_transform,
                      nodata=np.nan) as ds:
        ds.write(wrap.astype(rasterio.float32), 1)
        
    # scale wrapped interferogram (0 to 255)
    scaled_path = wrapped_path/f'{wrp_path.stem.split("_unscaled")[0]}_scaled.tif'
    # !gdal_translate -of GTiff -scale -ot BYTE $wrp_path $scaled_path
    wrp_path.unlink()
    
    # add color ramp
    colorize_wrapped_insar(scaled_path)
    
    # convert to 3-band rgb
    three_band_path = wrapped_path/f'{scaled_path.stem.split("_scaled")[0]}.tif'
    # !gdal_translate -of GTiff -expand rgb $scaled_path $three_band_path
    scaled_path.unlink()

# %% [markdown]
# **Save the temporal coherence geotiff**

# %%
# !save_gdal.py $mint_path/temporalCoherence.h5 --of GTIFF -o $geotiff_path/TemporalCoherence.tif

# %% [markdown]
# **Save the average spatial coherence geotiff**

# %%
# !save_gdal.py $mint_path/avgSpatialCoh.h5 --of GTIFF -o $geotiff_path/avgSpatialCoh.tif

# %% [markdown]
# **Save the velocity geotiff**

# %%
velocity_name = "velocity"
if correct_tropo:
    velocity_name = f'{velocity_name}ERA5'
vel_h5 = mint_path/f'{velocity_name}.h5'
vel_tiff = geotiff_path/f'{velocity_name}.tif'
# !save_gdal.py $vel_h5 --of GTIFF -o $vel_tiff

# %% [markdown]
# # Reference material

# %% [markdown]
# - Mintpy reference: *Yunjun, Z., H. Fattahi, F. Amelung (2019), Small baseline InSAR time series analysis: unwrapping error correction and noise reduction, preprint doi:[10.31223/osf.io/9sz6m](https://eartharxiv.org/9sz6m/).*
#
# - University of Miami online time-series viewer: https://insarmaps.miami.edu/
#
# - Mintpy Github repository: https://github.com/insarlab/MintPy

# %% [markdown]
# *MintPy_Time_Series_From_Prepared_Data_Stack.ipynb - Version 0.5.0 - Oct 2024*
#
# *Version Changes*
#
# - *GPS LOS comparison plot fixes*
# - *Note about CDS interruptions*
